# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('All_Errors_Corrected.csv',parse_dates=['Standardized_Date'])
data.head()
# Out:
#   Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 0        2024-08-01              1:00                 2561.58
# 1        2024-08-01              2:00                 2510.71
# 2        2024-08-01              3:00                 2489.32
# 3        2024-08-01              4:00                 2444.78
# 4        2024-08-01              5:00                 2417.47
#
#    CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 0                             2.32                        1996.36
# 1                             2.49                        1984.73
# 2                             2.71                        1998.56
# 3                             2.79                        1972.01
# 4                             2.99                        1945.42
#
#    TREATED WATER PRODUCTION IN m3/h REMARKS
# 0                           2479.10     NaN
# 1                           2429.87     NaN
# 2                           2409.16     NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24793 entries, 0 to 24792
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Standardized_Date                 24793 non-null  datetime64[ns]
#  1   STANDARDIZED_TIME                 24793 non-null  object
#  2   RAW WATER FLOW IN m3/h            24732 non-null  float64
#  3   CLEAR WATER SUMP LEVEL IN Meter   24696 non-null  float64
#  4   CLEAR WATER PUMPING FLOW m3/h     24761 non-null  float64
#  5   TREATED WATER PRODUCTION IN m3/h  24792 non-null  float64
#  6   REMARKS                           194 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 1.3+ MB

# %%
data[23513:23566]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 23513        2022-01-09             17:00                 1282.84
# 23514        2022-01-09             18:00                    0.00
# 23515        2022-01-09             19:00                    0.00
# 23516        2022-01-09             20:00                    0.00
# 23517        2022-01-09             21:00                    0.00
# 23518        2022-01-09             22:00                    0.00
# 23519        2022-01-09             23:00                    0.00
# 23520        2022-01-09              0:00                    0.00
# 23521        2022-01-10              1:00                    0.00
# 23522        2022-01-10              2:00                    0.00
# 23523        2022-01-10              3:00                    0.00
# 23524        2022-01-10              4:00                    0.00
# 23525        2022-01-10              5:00                    0.00
# ...

# %%
data.loc[23001:23003]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 23001        2022-02-16              9:00                 3604.19
# 23002        2022-02-16             10:00                    0.00
# 23003        2022-02-16             11:00                    0.00
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 23001                             3.33                        2781.45
# 23002                             0.00                           0.00
# 23003                             0.00                           0.00
#
#        TREATED WATER PRODUCTION IN m3/h          REMARKS
# 23001                           3488.14  PERMITTED POWER
# 23002                              0.00   FAILURE AT WTP
# 23003                              0.00              NaN

# %% [markdown]
# ### Remarks column correction

# %%
data.REMARKS.unique()
# Out:
# array([nan, 'Intake pumping well cleaning', 'power failure at intake',
#        'power failur at intake and wtp',
#        'Pumping stopped due to power failure at intake',
#        'Pumping stopped due to maintanance work at WTP and Intake',
#        'Pumping stopped for maintanance work & NHAI work.',
#        'RW pumping stopped', 'Power failure @ intake',
#        'Raw Water Reading not available due to PLC complaint.',
#        'power failure at 7.28 to 7.36 pm',
#        'Distribution line maintanance', 'Permitted power failure.',
#        'power failure', 'channel cieaning',
#        'stopped due to intake backwash', 'intake back wash',
#        'inlet chamber cleaning', 'power failure at wtp 6.03 to6.40am',
#        'Pumping stopped due to pipe line maintanance at taliparamba',
#        'power failur', 'Gravity line air valve maintenance',
#        'stopped for maintanance', 'power failuire at intake',
# ...

# %%
data['REMARKS'] = data['REMARKS'].str.lower()
Rem = data.REMARKS.value_counts().reset_index()
# Rem.index = Rem.index.lower
Rem
# Out:
#                                               REMARKS  count
# 0                                   twr tank cleaning     49
# 1                                       power failure     20
# 2                             intake chamber cleaning     19
# 3                              pumping stopped due to     17
# 4                             power failure at intake     13
# 5                                      sump level low      5
# 6                        pumping stoped due to intake      4
# 7                       distribution line maintanance      4
# 8                                                   1      3
# 9                                              intake      3
# 10                               power failure at wtp      3
# 11  pumping stoped due to permitted power failure ...      2
# 12                                    intake backwash      2
# 13                                      under voltage      2
# ...

# %%
data[data['REMARKS']=='maintenance work at']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 22697        2022-02-03             17:00                     0.0
# 22932        2022-02-13             12:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 22697                             2.40                            0.0
# 22932                             3.08                            0.0
#
#        TREATED WATER PRODUCTION IN m3/h              REMARKS
# 22697                               0.0  maintenance work at
# 22932                               0.0  maintenance work at

# %%
## REMARKS
#22697	2022-02-03	17:00	0.0	2.40	0.0	0.0	maintenance work at 
#22698	2022-02-03	18:00	0.0	2.09	0.0	0.0	intake

indices_maint = list(range(22697, 22699)) + \
          list(range(22932, 22934))
data.loc[indices_maint,'REMARKS'] = 'maintanance work at intake'
rows = data.loc[indices_maint]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 22697        2022-02-03             17:00                     0.0
# 22698        2022-02-03             18:00                     0.0
# 22932        2022-02-13             12:00                     0.0
# 22933        2022-02-13             13:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 22697                             2.40                            0.0
# 22698                             2.09                            0.0
# 22932                             3.08                            0.0
# 22933                             3.05                            0.0
#
#        TREATED WATER PRODUCTION IN m3/h                     REMARKS
# 22697                               0.0  maintanance work at intake
# 22698                               0.0  maintanance work at intake
# 22932                               0.0  maintanance work at intake
# ...

# %%
list1 = ['1','3','pumping started','power failure at 7.28 to 7.36 pm','power failure at wtp 6.03 to6.40am']
for i in range(len(data)):
    if data.loc[i,'REMARKS'] in list1:
        data.loc[i,'REMARKS'] = np.nan

# %%
data[(data['REMARKS']=='pumping stoped due to intake')|(data['REMARKS']=='pumping sopped due to inake')|(data['REMARKS']=='pumping stopped due to intake')]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 17218        2022-09-20             10:00                     0.0
# 19039        2022-07-04              7:00                     0.0
# 19054        2022-07-04             22:00                     0.0
# 19073        2022-07-05             17:00                     0.0
# 19086        2022-07-06              6:00                     0.0
# 19111        2022-07-07              7:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 17218                             3.38                           0.00
# 19039                             2.94                           0.00
# 19054                             2.65                        1848.71
# 19073                             3.67                           0.00
# 19086                             3.05                           0.00
# 19111                             2.85                           0.00
#
# ...

# %%
## REMARKS
# 19039	2022-07-04	7:00	0.0	2.94	0.00	0.0	pumping stoped due to intake
# 19040	2022-07-04	8:00	0.0	2.64	0.00	0.0	sump level low

indices_sump = list(range(19039, 19041)) + \
            list(range(19054, 19056)) + \
          list(range(19073, 19075)) + \
          list(range(19086, 19088)) + \
          list(range(19111, 19113))
data.loc[indices_sump,'REMARKS'] = 'intake sump level low'
rows = data.loc[indices_sump]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 19039        2022-07-04              7:00                     0.0
# 19040        2022-07-04              8:00                     0.0
# 19054        2022-07-04             22:00                     0.0
# 19055        2022-07-04             23:00                     0.0
# 19073        2022-07-05             17:00                     0.0
# 19074        2022-07-05             18:00                     0.0
# 19086        2022-07-06              6:00                     0.0
# 19087        2022-07-06              7:00                     0.0
# 19111        2022-07-07              7:00                     0.0
# 19112        2022-07-07              8:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 19039                             2.94                           0.00
# 19040                             2.64                           0.00
# ...

# %%
## REMARKS
# 17218	2022-09-20	10:00	0.0	3.38	0.0	0.0	pumping sopped due to inake
# 17219	2022-09-20	11:00	0.0	3.34	0.0	0.0	chamber cleaning

indices_chamber = list(range(17218, 17220))
data.loc[indices_chamber,'REMARKS'] = 'intake chamber cleaning'
rows = data.loc[indices_chamber]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 17218        2022-09-20             10:00                     0.0
# 17219        2022-09-20             11:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 17218                             3.38                            0.0
# 17219                             3.34                            0.0
#
#        TREATED WATER PRODUCTION IN m3/h                  REMARKS
# 17218                               0.0  intake chamber cleaning
# 17219                               0.0  intake chamber cleaning

# %%
## REMARKS
# 16257	2022-10-11	9:00	0.00	2.72	0.00	0.00	pumping stopped due to
# 16258	2022-10-11	10:00	0.00	2.66	0.00	0.00	intake chamber cleaning

indices_chamber = list(range(16257, 16259)) + \
          list(range(17265, 17267)) + \
          list(range(17914, 17916)) + \
          list(range(17938, 17940)) + \
          list(range(17960, 17962)) + \
          list(range(17987, 17989)) + \
          list(range(18034, 18036)) + \
          list(range(18058, 18060)) + \
          list(range(18658, 18660)) + \
          list(range(18682, 18684)) + \
          list(range(18704, 18706)) + \
          list(range(18731, 18733)) + \
          list(range(18778, 18780)) + \
          list(range(18802, 18804)) #+ \
#           list(range(20034, 20036)) + \
#           list(range(21814, 21816)) + \
#           list(range(21848, 21850)) 
data.loc[indices_chamber,'REMARKS'] = 'intake chamber cleaning'
rows = data.loc[indices_chamber]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 16257        2022-10-11              9:00                    0.00
# 16258        2022-10-11             10:00                    0.00
# 17265        2022-09-22              9:00                 3284.23
# 17266        2022-09-22             10:00                    0.00
# 17914        2022-08-19             10:00                    0.00
# 17915        2022-08-19             11:00                    0.00
# 17938        2022-08-20             10:00                    0.00
# 17939        2022-08-20             11:00                    0.00
# 17960        2022-08-21              8:00                 3239.05
# 17961        2022-08-21              9:00                    0.00
# 17987        2022-08-22             11:00                    0.00
# 17988        2022-08-22             12:00                    0.00
# 18034        2022-08-24             10:00                    0.00
# ...

# %%
## REMARKS
# 20034	2022-06-14	18:00	0.0	3.12	0.0	0.0	pumping stopped due to
# 20035	2022-06-14	19:00	0.0	3.10	0.0	0.0	pipe line broken at taliparamba
# 21814	2022-04-27	22:00	NaN	NaN	NaN	0.0	pumping stopped due to
# 21815	2022-04-27	23:00	NaN	NaN	NaN	0.0	maintenance at thaliparamba

indices_thaliparambu =list(range(20034, 20036)) + \
          list(range(21814, 21816))
data.loc[indices_thaliparambu,'REMARKS'] = 'issue at Thaliparambu'

## REMARKS
# 21848	2022-04-29	8:00	0.0	2.0	0.0	0.0	pumping stopped due to
# 21849	2022-04-29	9:00	0.0	2.0	0.0	0.0	maintenance work at intake

indices_maintain =list(range(21848, 21850)) 
data.loc[indices_maintain,'REMARKS'] = 'maintanance work at intake'
rows = data.loc[indices_thaliparambu]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 20034        2022-06-14             18:00                     0.0
# 20035        2022-06-14             19:00                     0.0
# 21814        2022-04-27             22:00                     NaN
# 21815        2022-04-27             23:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 20034                             3.12                            0.0
# 20035                             3.10                            0.0
# 21814                              NaN                            NaN
# 21815                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h                REMARKS
# 20034                               0.0  issue at Thaliparambu
# 20035                               0.0  issue at Thaliparambu
# 21814                               0.0  issue at Thaliparambu
# ...

# %%
data[data.REMARKS=='power failed @9.45 to 2.25']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 13328        2023-02-09              9:00                 3532.62
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 13328                             2.93                        2787.92
#
#        TREATED WATER PRODUCTION IN m3/h                     REMARKS
# 13328                           3418.87  power failed @9.45 to 2.25

# %%
data.loc[13328,'REMARKS'] = np.nan
data.loc[13329,'REMARKS'] = 'power failure at intake and WTP'

# %%
## REMARKS
# 23001	2022-02-16	9:00	3604.19	3.33	2781.45	3488.14	permitted power
# 23002	2022-02-16	10:00	0.00	0.00	0.00	0.00	failure at wtp

indices_wtp_power =list(range(23002, 23003)) 
data.loc[indices_wtp_power,'REMARKS'] = 'power failure at WTP'
data.loc[23001,'REMARKS'] = np.nan
rows = data.loc[indices_wtp_power]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 23002        2022-02-16             10:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 23002                              0.0                            0.0
#
#        TREATED WATER PRODUCTION IN m3/h               REMARKS
# 23002                               0.0  power failure at WTP

# %%
## REMARKS
# 22497	2022-03-26	9:00	NaN	NaN	NaN	0.0	informed power failure at
# 22498	2022-03-26	10:00	NaN	NaN	NaN	0.0	intake

indices_intake_power = [22497,22498]
data.loc[indices_intake_power,'REMARKS'] = 'power failure at intake'
rows = data.loc[indices_intake_power]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 22497        2022-03-26              9:00                     NaN
# 22498        2022-03-26             10:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 22497                              NaN                            NaN
# 22498                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h                  REMARKS
# 22497                               0.0  power failure at intake
# 22498                               0.0  power failure at intake

# %%
data[13328:13334]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 13328        2023-02-09              9:00                 3532.62
# 13329        2023-02-09             10:00                    0.00
# 13330        2023-02-09             11:00                    0.00
# 13331        2023-02-09             12:00                    0.00
# 13332        2023-02-09             13:00                    0.00
# 13333        2023-02-09             14:00                    0.00
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 13328                             2.93                        2787.92
# 13329                             3.31                           0.00
# 13330                             2.98                           0.00
# 13331                             2.73                           0.00
# 13332                             2.46                           0.00
# 13333                             2.31                           0.00
#
# ...

# %%
data[data.REMARKS=='rw pumping stopped']
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 5173        2024-01-06             14:00                 1265.45
#
#       CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 5173                             3.92                            0.0
#
#       TREATED WATER PRODUCTION IN m3/h             REMARKS
# 5173                            1224.7  rw pumping stopped

# %%
data[5173:5175]
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 5173        2024-01-06             14:00                 1265.45
# 5174        2024-01-06             15:00                    0.00
#
#       CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 5173                             3.92                            0.0
# 5174                             3.81                            0.0
#
#       TREATED WATER PRODUCTION IN m3/h             REMARKS
# 5173                            1224.7  rw pumping stopped
# 5174                               0.0                 NaN

# %%
# 20938	2022-05-22	10:00	2475.82	3.92	2842.36	2396.10	power failure	
data.loc[20938,'REMARKS'] = np.nan

# %%
data[5172:5195]
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 5172        2024-01-06             13:00                 1288.54
# 5173        2024-01-06             14:00                 1265.45
# 5174        2024-01-06             15:00                    0.00
# 5175        2024-01-06             16:00                    0.00
# 5176        2024-01-06             17:00                    0.00
# 5177        2024-01-06             18:00                    0.00
# 5178        2024-01-06             19:00                    0.00
# 5179        2024-01-06             20:00                    0.00
# 5180        2024-01-06             21:00                    0.00
# 5181        2024-01-06             22:00                    0.00
# 5182        2024-01-06             23:00                    0.00
# 5183        2024-01-06              0:00                    0.00
# 5184        2024-01-07              1:00                    0.00
# ...

# %%
# 5173	2024-01-06	14:00	1265.45	3.92	0.00	1224.70	rw pumping stopped
data.loc[5173,'REMARKS'] = np.nan
data.loc[5174,'REMARKS'] = 'intake pumping stopped'

# %%
data['REMARKS'] = data['REMARKS'].str.lower()
Rem = data.REMARKS.value_counts().reset_index()
# Rem.index = Rem.index.lower
Rem
# Out:
#                                               REMARKS  count
# 0                                   twr tank cleaning     49
# 1                             intake chamber cleaning     35
# 2                                       power failure     19
# 3                             power failure at intake     15
# 4                               intake sump level low     10
# 5                          maintanance work at intake      6
# 6                               issue at thaliparambu      4
# 7                       distribution line maintanance      4
# 8                                power failure at wtp      4
# 9                                       under voltage      2
# 10                                    intake backwash      2
# 11  pumping stopped due to pipe line maintanance a...      2
# 12                             inlet chamber cleaning      2
# 13                       intake pumping well cleaning      2
# ...

# %%
# data[data['REMARKS']=='pumping stopped due to']

# %%
# data[17224:17227]

# %%
# data[data['REMARKS']=='pumping stopped due to intake']

# %%
# data[17218:17221] #

# %%
# data[22696:22700]

# %%
# data[22932:22937]

# %%
# data[data.REMARKS=='intake']

# %%
# data[data['RAW WATER FLOW IN m3/h'].isna()]

# %%
# data.iloc[22490:22510]

# %%
# data.REMARKS.nunique()

# %%
# data[data['REMARKS'].str.contains('intake', case=False) & data['REMARKS'].str.contains('power', case=False)]

# %%
# data[data['REMARKS'].str.contains('intake', case=False) & data['REMARKS'].str.contains('power', case=False)].shape

# %%
# data[(data['REMARKS'].str.contains('intake', case=False)) & (data['REMARKS'].str.contains('power', case=False))&(data['REMARKS'].str.contains('wtp', case=False)==False)]

# %%
# data[(data['REMARKS'].str.contains('intake', case=False)) & (data['REMARKS'].str.contains('power', case=False))&(data['REMARKS'].str.contains('wtp', case=False)==False)].shape

# %%
# data[(data['REMARKS'].str.contains('intake', case=False)==False) & (data['REMARKS'].str.contains('power', case=False))&(data['REMARKS'].str.contains('wtp', case=False))].shape

# %%
# data.loc[14217,'REMARKS']

# %% [markdown]
# ## Categorize REMARKS column

# %%
df = data.copy()

# %%
def categorize_remarks(data):
    """
    Categorizes the remarks column based on specific conditions:
    1. 'Power Failure at Intake' if:
       - Contains 'intake' (case-insensitive)
       - Contains 'power' (case-insensitive)
       - Does not contain 'wtp' (case-insensitive)
    
    2. 'Power Failure at WTP' if:
       - Does not contain 'intake'
       - Contains 'power' (case-insensitive)
       - Contains 'wtp' (case-insensitive)
    """
    
    def categorize(row):
        remarks = row['REMARKS']
        raw_water = row['RAW WATER FLOW IN m3/h']
        clear_water_pumping = row['CLEAR WATER PUMPING FLOW m3/h']
        if pd.notna(remarks):
            remarks_lower = remarks.lower()
            if ('intake' in remarks_lower and ('power' in remarks_lower or 'failure' in remarks_lower) and 'wtp' not in remarks_lower) or (('power' in remarks_lower or 'failure' in remarks_lower) and 'wtp' not in remarks_lower and (raw_water == 0.0 or pd.isna(raw_water)) and not pd.isna(clear_water_pumping) and clear_water_pumping != 0.0):
                return 'Power Failure at Intake'
            elif ('intake' not in remarks_lower and ('power' in remarks_lower or 'failure' in remarks_lower) and 'wtp' in remarks_lower) or (('power' in remarks_lower or 'failure' in remarks_lower) and 'intake' not in remarks_lower and not pd.isna(raw_water) and raw_water !=0.0 and (clear_water_pumping == 0.0 or pd.isna(clear_water_pumping))):
                return 'Power Failure at WTP'
            elif ('intake' in remarks_lower and ('power' in remarks_lower or 'failure' in remarks_lower) and 'wtp' in remarks_lower) or ('intake' not in remarks_lower and 'wtp' not in remarks_lower and ('power' in remarks_lower or 'failure' in remarks_lower) and (raw_water == 0.0 or pd.isna(raw_water)) and (clear_water_pumping == 0.0 or pd.isna(clear_water_pumping))):
                return 'Power Failure at intake and WTP'
            elif (('cleaning' in remarks_lower or 'wash' in remarks_lower) and 'intake' in remarks_lower):
                return 'intake cleaning'
            elif 'maint' in remarks_lower:
                return 'maintanance'
#             elif 'intake sump level low' in remarks_lower:
#                 return 'intake sump level low'
#             elif 'energy auditing' in remarks_lower:
#                 return 'energy auditing'
#             elif 'issue at thaliparambu' in remarks_lower:
#                 return 'issue at thaliparambu'
            elif 'cleaning' in remarks_lower and ('twr' in remarks_lower or 'wtp' in remarks_lower):
                return 'WTP cleaning'
#             elif 'intake pumping stopped' in remarks_lower:
#                 return 'intake pumping stopped'
            elif 'plc complaint' in remarks_lower:
                return 'complaint at WTP'
            else:
                return remarks_lower
            
#         return ''

    # Apply the categorization function to each row
    data['remarks category'] = data.apply(categorize, axis=1)
    
    return data

# %%
df = categorize_remarks(df)
df
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 0            2024-08-01              1:00                 2561.58
# 1            2024-08-01              2:00                 2510.71
# 2            2024-08-01              3:00                 2489.32
# 3            2024-08-01              4:00                 2444.78
# 4            2024-08-01              5:00                 2417.47
# ...                 ...               ...                     ...
# 24788        2021-12-31             20:00                 2499.51
# 24789        2021-12-31             21:00                 2477.10
# 24790        2021-12-31             22:00                 2470.76
# 24791        2021-12-31             23:00                 2492.04
# 24792        2021-12-31              0:00                 2494.18
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 0                                 2.32                        1996.36
# ...

# %%
# df[df['remarks category'].notna()]

# %%
# data[(data['REMARKS'].str.contains('intake', case=False)) & (data['REMARKS'].str.contains('power', case=False))&(data['REMARKS'].str.contains('wtp', case=False))]

# %%
# df[df['remarks category'].notna()].shape

# %%
# df.REMARKS.nunique()

# %%
df[df['remarks category'].isna()].REMARKS.nunique()
# Out:
# 0

# %%
remain_list = list(df[df['remarks category'].isna()].REMARKS.unique())
remain_list
# Out:
# [nan]

# %% [markdown]
# ## Filling 'remarks category' column

# %%
# Function to fill NaN values in 'remarks category' based on the conditions
def fill_remarks_category(df):
    previous_remark = None
#     remarks_flag=False
    for i in range(len(df)):
        current_remark = df.loc[i, 'remarks category']
        raw_water_flow = df.loc[i, 'RAW WATER FLOW IN m3/h']
        clear_water_pumping_flow = df.loc[i, 'CLEAR WATER PUMPING FLOW m3/h']
        # Check if 'remarks category' is NaN and if the previous row had a non-NaN remark
        if pd.isna(current_remark):
            # Check if raw water and treated water columns are 0 or NaN
            if ((raw_water_flow == 0 or pd.isna(raw_water_flow)) and (clear_water_pumping_flow == 0 or pd.isna(clear_water_pumping_flow))):# or (('intake' in previous_remark) and (raw_water_flow == 0) and (clear_water_pumping_flow != 0)) or (('WTP' in previous_remark) and (raw_water_flow != 0) and (clear_water_pumping_flow == 0)):
                # Fill the current NaN remark with the previous non-NaN remark
                df.loc[i, 'remarks category'] = previous_remark
            elif previous_remark is not None and (('intake' in previous_remark and 'WTP' not in previous_remark and (raw_water_flow == 0 or pd.isna(raw_water_flow)) and clear_water_pumping_flow != 0) or ('WTP' in previous_remark and 'intake' not in previous_remark and raw_water_flow != 0 and (clear_water_pumping_flow == 0 or pd.isna(clear_water_pumping_flow)))):
                df.loc[i, 'remarks category'] = previous_remark
            elif previous_remark is not None and 'complaint at WTP' in previous_remark and (raw_water_flow == 0 or pd.isna(raw_water_flow)):
                df.loc[i, 'remarks category'] = previous_remark
#             elif previous_remark is not None and 'WTP cleaning' in previous_remark and (raw_water_flow == 0 or pd.isna(raw_water_flow)) and (clear_water_flow == 0 or pd.isna(clear_water_flow)):
#                 df.loc[i, 'remarks category'] = previous_remark
            else:
                previous_remark = current_remark
        else:
            # Update the previous_remark if the current remark is not NaN
            previous_remark = current_remark
 
    return df

# %%
# Apply the function to the DataFrame
df_filled = fill_remarks_category(df)

# %%
df_filled
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 0            2024-08-01              1:00                 2561.58
# 1            2024-08-01              2:00                 2510.71
# 2            2024-08-01              3:00                 2489.32
# 3            2024-08-01              4:00                 2444.78
# 4            2024-08-01              5:00                 2417.47
# ...                 ...               ...                     ...
# 24788        2021-12-31             20:00                 2499.51
# 24789        2021-12-31             21:00                 2477.10
# 24790        2021-12-31             22:00                 2470.76
# 24791        2021-12-31             23:00                 2492.04
# 24792        2021-12-31              0:00                 2494.18
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 0                                 2.32                        1996.36
# ...

# %%
df_filled[df_filled['remarks category'].isna()].REMARKS.unique()
# Out:
# array([nan], dtype=object)

# %%
df_filled['remarks category'].value_counts()
# Out:
# remarks category
# intake cleaning                    152
# maintanance                        131
# Power Failure at Intake            118
# issue at thaliparambu               85
# Power Failure at intake and WTP     57
# WTP cleaning                        51
# complaint at WTP                    33
# under voltage                       32
# Power Failure at WTP                25
# intake sump level low               22
# intake pumping stopped              13
# channel cieaning                    10
# inlet chamber cleaning               4
# voltage fluctation at intake         4
# energy auditing                      1
# Name: count, dtype: int64

# %%
df_filled[df_filled['remarks category']=='issue at thaliparambu'].head(50)
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 20034        2022-06-14             18:00                     0.0
# 20035        2022-06-14             19:00                     0.0
# 20036        2022-06-14             20:00                     0.0
# 20037        2022-06-14             21:00                     0.0
# 20038        2022-06-14             22:00                     0.0
# 20039        2022-06-14             23:00                     0.0
# 20040        2022-06-14              0:00                     0.0
# 20041        2022-06-15              1:00                     0.0
# 20042        2022-06-15              2:00                     0.0
# 20043        2022-06-15              3:00                     0.0
# 20044        2022-06-15              4:00                     0.0
# 20045        2022-06-15              5:00                     0.0
# 20046        2022-06-15              6:00                     0.0
# ...

# %%
df_filled[21475:21487]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 21475        2022-04-13             19:00                 2475.67
# 21476        2022-04-13             20:00                    0.00
# 21477        2022-04-13             21:00                    0.00
# 21478        2022-04-13             22:00                    0.00
# 21479        2022-04-13             23:00                    0.00
# 21480        2022-04-13              0:00                    0.00
# 21481        2022-04-14              1:00                    0.00
# 21482        2022-04-14              2:00                    0.00
# 21483        2022-04-14              3:00                    0.00
# 21484        2022-04-14              4:00                    0.00
# 21485        2022-04-14              5:00                 2512.65
# 21486        2022-04-14              6:00                 2497.54
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# ...

# %%
data.loc[23001:23003]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 23001        2022-02-16              9:00                 3604.19
# 23002        2022-02-16             10:00                    0.00
# 23003        2022-02-16             11:00                    0.00
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 23001                             3.33                        2781.45
# 23002                             0.00                           0.00
# 23003                             0.00                           0.00
#
#        TREATED WATER PRODUCTION IN m3/h               REMARKS
# 23001                           3488.14  power failure at wtp
# 23002                              0.00  power failure at wtp
# 23003                              0.00                   NaN

# %%
df_filled[5150:5189]
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 5150        2024-01-05             15:00                    0.00
# 5151        2024-01-05             16:00                    0.00
# 5152        2024-01-05             17:00                    0.00
# 5153        2024-01-05             18:00                    0.00
# 5154        2024-01-05             19:00                    0.00
# 5155        2024-01-05             20:00                    0.00
# 5156        2024-01-05             21:00                    0.00
# 5157        2024-01-05             22:00                    0.00
# 5158        2024-01-05             23:00                    0.00
# 5159        2024-01-05              0:00                    0.00
# 5160        2024-01-06              1:00                    0.00
# 5161        2024-01-06              2:00                    0.00
# 5162        2024-01-06              3:00                    0.00
# ...

# %%
df_filled[df_filled['remarks category']=='complaint at WTP']
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 6200        2023-12-18              9:00                     NaN
# 6201        2023-12-18             10:00                     NaN
#
#       CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 6200                             2.81                        3669.64
# 6201                             2.29                        3648.43
#
#       TREATED WATER PRODUCTION IN m3/h  \
# 6200                               0.0
# 6201                               0.0
#
#                                                 REMARKS  remarks category
# 6200  raw water reading not available due to plc com...  complaint at WTP
# 6201  raw water reading not available due to plc com...  complaint at WTP

# %%
df[6200:6234]
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 6200        2023-12-18              9:00                     NaN
# 6201        2023-12-18             10:00                     NaN
# 6202        2023-12-18             11:00                     NaN
# 6203        2023-12-18             12:00                     NaN
# 6204        2023-12-18             13:00                     NaN
# 6205        2023-12-18             14:00                     NaN
# 6206        2023-12-18             15:00                     NaN
# 6207        2023-12-18             16:00                     NaN
# 6208        2023-12-18             17:00                     NaN
# 6209        2023-12-18             18:00                     NaN
# 6210        2023-12-18             19:00                     NaN
# 6211        2023-12-18             20:00                     NaN
# 6212        2023-12-18             21:00                     NaN
# ...

# %%
df[(df.REMARKS=='rw pumping stopped')]# & (df['RAW WATER FLOW IN m3/h'] == np.nan)]

# %%
df[(df.REMARKS=='power failure')]

# %%
df[df['remarks category']=='Power Failure at Intake']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 2202         2024-05-03             19:00                     0.0
# 2203         2024-05-03             20:00                     0.0
# 2204         2024-05-03             21:00                     0.0
# 2205         2024-05-03             22:00                     0.0
# 2206         2024-05-03             23:00                     0.0
# ...                 ...               ...                     ...
# 23799        2022-01-21             15:00                     0.0
# 23800        2022-01-21             16:00                     0.0
# 23801        2022-01-21             17:00                     0.0
# 23802        2022-01-21             18:00                     0.0
# 23970        2022-01-28             18:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 2202                              3.88                           0.00
# ...

# %%
df.loc[23793:23804]

# %%
wtp_list = list(df[df['remarks category']=='Power Failure at WTP'].index)

# %%
df.loc[wtp_list]

# %%
intake_list = list(df[df['remarks category']=='Power Failure at Intake'].index)

# %%
df.loc[intake_list]

# %%
df['remarks category'].isna().sum()

# %%
# df.shape

# %% [markdown]
# ## Filling remarks column

# %%
def fill_power_failure_remarks(data,column_name,remark):
    """
    Fill the 'remarks' column with 'power failure' for all rows where the 'value' column is 0.0,
    starting from the first occurrence of 'power failure' in the remarks.
    
    :param data: DataFrame with 'time', 'value', and 'remarks' columns
    :return: DataFrame with updated 'remarks' column
    """
    power_failure_flag = False  # Flag to track power failure status
    
    for i in range(len(data)):
        # If power failure is detected in the remarks column
        if data.loc[i, 'remarks category'] == remark: #and data.loc[i, column_name] == 0.0:
            power_failure_flag = True
        
        # If power failure flag is set and value is still 0.0, keep filling 'power failure'
        if power_failure_flag and data.loc[i, column_name] == 0.0:
            data.loc[i, 'remarks category'] = remark
        else:
            # Reset flag when power comes back (value is not 0.0)
            power_failure_flag = False
    
    return data

# %%
def fill_power_failure_remarks2(data,column_name1,column_name2,remark):
    """
    Fill the 'remarks' column with 'power failure' for all rows where the 'value' column is 0.0,
    starting from the first occurrence of 'power failure' in the remarks.
    
    :param data: DataFrame with 'time', 'value', and 'remarks' columns
    :return: DataFrame with updated 'remarks' column
    """
    power_failure_flag = False  # Flag to track power failure status
    
    for i in range(len(data)):
        # If power failure is detected in the remarks column
        if data.loc[i, 'remarks category'] == remark: #and data.loc[i, column_name] == 0.0:
            power_failure_flag = True
        
        # If power failure flag is set and value is still 0.0, keep filling 'power failure'
        if power_failure_flag and data.loc[i, column_name1] == 0.0 and data.loc[i, column_name2] == 0.0:
            data.loc[i, 'remarks category'] = remark
        else:
            # Reset flag when power comes back (value is not 0.0)
            power_failure_flag = False
    
    return data

# %%
df = fill_power_failure_remarks(df,'RAW WATER FLOW IN m3/h','Power Failure at Intake')

# %%
df['remarks category'].isna().sum()

# %%
df = fill_power_failure_remarks(df,'TREATED WATER PRODUCTION IN m3/h','Power Failure at WTP')

# %%
df['remarks category'].isna().sum()

# %%
df = fill_power_failure_remarks2(df,'RAW WATER FLOW IN m3/h','TREATED WATER PRODUCTION IN m3/h','Power Failure at intake and WTP')

# %%
df['remarks category'].isna().sum()

# %%
df[df['remarks category']=='Power Failure at intake and WTP']

# %%
df.loc[22497:22510]

# %%
df.iloc[17217:17220]

# %% [markdown]
# ## Outlier detection

# %%
indices = list(range(8, 15)) + \
          list(range(1870, 1875)) + \
          list(range(2460, 2467)) + \
          list(range(3290, 3295)) + \
          list(range(3350, 3355)) + \
          list(range(3450, 3455)) + \
          list(range(3690, 3692)) + \
          list(range(4540, 4545)) + \
          list(range(6790, 6795)) + \
          list(range(7775, 7775)) + \
          list(range(8638, 8642)) + \
          list(range(11410, 11413)) + \
          list(range(12902, 12905)) + \
          list(range(13890, 13895)) + \
          list(range(21200, 21204)) + \
          list(range(23180, 23185)) 
rows = df.loc[indices]
rows

# %%
df[df['RAW WATER FLOW IN m3/h']>=4000]

# %%
# indices = list(range(10, 14)) + \
#           list(range(1870, 1874)) + \
#           list(range(2462, 2466)) + \
#           list(range(3291, 3295)) + \
#           list(range(3353, 3357)) + \
#           list(range(3452, 3456)) + \
#           list(range(3689, 3693)) + \
#           list(range(4539, 4543)) + \
#           list(range(6789, 6793)) + \
#           list(range(7775, 7779)) + \
#           list(range(8638, 8642)) + \
#           list(range(11409, 11413)) + \
#           list(range(12902, 12906)) + \
#           list(range(13891, 13895)) + \
#           list(range(21199, 21203)) + \
#           list(range(23181, 23185))
# rows = df.loc[indices]
# rows

# %%
df['RAW WATER FLOW IN m3/h'].isna().sum()

# %%
# df['RAW WATER FLOW IN m3/h'].where(df['RAW WATER FLOW IN m3/h'] <= 4000).isna().sum()

# %%
df[df['CLEAR WATER SUMP LEVEL IN Meter']>5]

# %%
df['CLEAR WATER SUMP LEVEL IN Meter'].isna().sum()

# %%
df['CLEAR WATER PUMPING FLOW m3/h'].isna().sum()

# %%
df[df['CLEAR WATER PUMPING FLOW m3/h']>4000].shape

# %%
for i in range(1, len(data)):
        # If the value is greater than the threshold
        if df.loc[i, 'CLEAR WATER PUMPING FLOW m3/h'] > 4000:
            # Forward fill using the previous value
            print('index is ', i)
            print('previous value = ', df.loc[i-1, 'CLEAR WATER PUMPING FLOW m3/h'])
            print('outlier = ', df.loc[i, 'CLEAR WATER PUMPING FLOW m3/h'])

# %%
clear_water_list = list(df[df['CLEAR WATER PUMPING FLOW m3/h']>4000].index)
clear_water_list

# %%
df.loc[clear_water_list]

# %%
def raw_water_outlier_ffill(data, column_name1,column_name2, column_name3, threshold1=4000,threshold2=5, threshold3=4000):
    # Apply forward fill only to values greater than the threshold
#     data[column_name] = data[column_name].where(data[column_name] <= threshold).ffill()

#     temp_col = data[column_name].copy()
    
#     # Apply forward fill only to the values greater than the threshold
#     temp_col[temp_col > threshold] = temp_col[temp_col > threshold].ffill()
    
#     # Update only the values greater than the threshold in the original column
#     data.loc[data[column_name] > threshold, column_name] = temp_col

    for i in range(1, len(data)):
        # If the value is greater than the threshold
        if data.loc[i, column_name1] >= threshold1:
            # Forward fill using the previous value
            data.loc[i, column_name1] = data.loc[i-1, column_name1]
            data.loc[i,'TREATED WATER PRODUCTION IN m3/h'] = (data.loc[i, column_name1]*0.967).round(2)
            
    for i in range(1, len(data)):
        # If the value is greater than the threshold
        if data.loc[i, column_name2] > threshold2:
            # Forward fill using the previous value
            data.loc[i, column_name2] = data.loc[i-1, column_name2]
            
    for i in range(1, len(data)):
        # If the value is greater than the threshold
        if data.loc[i, column_name3] > threshold3:
            # Forward fill using the previous value
            data.loc[i, column_name3] = data.loc[i-1, column_name3]
    return data

# %%
df[df['RAW WATER FLOW IN m3/h'] > 4000]['RAW WATER FLOW IN m3/h']# = temp_col[temp_col > threshold].ffill()

# %%
# df[df['RAW WATER FLOW IN m3/h'] > 4000]['RAW WATER FLOW IN m3/h'] = df[df['RAW WATER FLOW IN m3/h'] > 4000]['RAW WATER FLOW IN m3/h'].ffill()

# %%
df = raw_water_outlier_ffill(df,'RAW WATER FLOW IN m3/h','CLEAR WATER SUMP LEVEL IN Meter','CLEAR WATER PUMPING FLOW m3/h')
df

# %%
df.loc[clear_water_list]

# %%
df[df['RAW WATER FLOW IN m3/h']>=4000]

# %%
df[df['CLEAR WATER SUMP LEVEL IN Meter']>5]

# %%
df[df['CLEAR WATER PUMPING FLOW m3/h'] > 4000]

# %%
indices = list(range(10, 15)) + \
          list(range(1870, 1875)) + \
          list(range(2462, 2467)) + \
          list(range(3291, 3296)) + \
          list(range(3353, 3358)) + \
          list(range(3452, 3457)) + \
          list(range(3689, 3694)) + \
          list(range(4539, 4544)) + \
          list(range(6789, 6794)) + \
          list(range(7775, 7780)) + \
          list(range(8638, 8643)) + \
          list(range(11409, 11414)) + \
          list(range(12902, 12907)) + \
          list(range(13891, 13896)) + \
          list(range(21199, 21204)) + \
          list(range(23181, 23186))
rows = df.loc[indices]
rows

# %%
# df['RAW WATER FLOW IN m3/h'].where(df['RAW WATER FLOW IN m3/h'] <= 4000).isna().sum()

# %%
df['RAW WATER FLOW IN m3/h'].isna().sum()

# %%
df['CLEAR WATER SUMP LEVEL IN Meter'].isna().sum()

# %%
df[df['CLEAR WATER SUMP LEVEL IN Meter']>5]

# %%
df['CLEAR WATER PUMPING FLOW m3/h'].isna().sum()
