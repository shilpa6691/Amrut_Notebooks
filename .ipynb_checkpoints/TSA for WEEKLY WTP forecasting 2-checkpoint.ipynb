# %%
import pandas as pd

# %%
df=pd.read_csv('Cleaned_Pattuvam_historic_data_till_July.csv')

# %%
df
# Out:
#        Unnamed: 0        DATE      TIME  RAW WATER FLOW IN ML  \
# 0               0  2021-12-01  01:00:00               3.51043
# 1               1  2021-12-01  02:00:00               3.49087
# 2               2  2021-12-01  03:00:00               3.50543
# 3               3  2021-12-01  04:00:00               3.51556
# 4               4  2021-12-01  05:00:00               3.50732
# ...           ...         ...       ...                   ...
# 23372       23372  2024-07-31  20:00:00               2.62182
# 23373       23373  2024-07-31  21:00:00               2.58243
# 23374       23374  2024-07-31  22:00:00               2.55854
# 23375       23375  2024-07-31  23:00:00               2.56037
# 23376       23376  2024-07-31  00:00:00               2.54326
#
#       CLEAR WATER SUMP LEVEL IN M  CLEAR WATER PUMPING FLOW ML  \
# 0                            2.84                      2.77743
# 1                            3.12                      2.79467
# 2                            3.44                      2.79543
# 3                            3.72                      2.79826
# 4                            4.01                      2.80887
# ...                           ...                          ...
# 23372                        2.87                      2.89854
# 23373                        2.51                      2.89954
# 23374                        2.23                      2.86554
# 23375                         1.7                      1.95539
# 23376                        1.77                      1.94328
#
#        TREATED WATER PRODUCTION IN ML     REMARKS             DATETIME  Hour  \
# 0                             3.39739  No Remarks  2021-12-01 01:00:00     1
# 1                             3.37846  No Remarks  2021-12-01 02:00:00     2
# 2                             3.39256  No Remarks  2021-12-01 03:00:00     3
# 3                             3.40236  No Remarks  2021-12-01 04:00:00     4
# 4                             3.39438  No Remarks  2021-12-01 05:00:00     5
# ...                               ...         ...                  ...   ...
# 23372                         2.53740  No Remarks  2024-07-31 20:00:00    20
# 23373                         2.49928  No Remarks  2024-07-31 21:00:00    21
# 23374                         2.47616  No Remarks  2024-07-31 22:00:00    22
# 23375                         2.47793  No Remarks  2024-07-31 23:00:00    23
# 23376                         2.46137  No Remarks  2024-07-31 00:00:00     0
#
#        YEAR  MONTH MONTH-YEAR
# 0      2021     12    12-2021
# 1      2021     12    12-2021
# 2      2021     12    12-2021
# 3      2021     12    12-2021
# 4      2021     12    12-2021
# ...     ...    ...        ...
# 23372  2024      7    07-2024
# 23373  2024      7    07-2024
# 23374  2024      7    07-2024
# 23375  2024      7    07-2024
# 23376  2024      7    07-2024
#
# [23377 rows x 13 columns]

# %%
df=df[['DATETIME','TREATED WATER PRODUCTION IN ML','REMARKS']]

# %%
df.dtypes
# Out:
# DATETIME                           object
# TREATED WATER PRODUCTION IN ML    float64
# REMARKS                            object
# dtype: object

# %%
df['DATETIME'] = pd.to_datetime(df['DATETIME'])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_29412\3960539372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATETIME'] = pd.to_datetime(df['DATETIME'])

# %%
df.set_index('DATETIME',inplace=True)

# %% [markdown]
# # Weekly Resampling

# %%
df = df.resample('D').sum(numeric_only=True)
df
# Out:
#             TREATED WATER PRODUCTION IN ML
# DATETIME
# 2021-12-01                        47.38883
# 2021-12-02                        75.13685
# 2021-12-03                        47.23406
# 2021-12-04                        47.06173
# 2021-12-05                        53.32709
# ...                                    ...
# 2024-07-27                        41.11649
# 2024-07-28                        62.82781
# 2024-07-29                        46.00382
# 2024-07-30                        43.74628
# 2024-07-31                        51.60935
#
# [974 rows x 1 columns]

# %%
df = df.resample('W')['TREATED WATER PRODUCTION IN ML'].sum()
df = df.reset_index()
df = df.set_index('DATETIME')
df
# Out:
#             TREATED WATER PRODUCTION IN ML
# DATETIME
# 2021-12-05                       270.14856
# 2021-12-12                       447.63063
# 2021-12-19                       436.71396
# 2021-12-26                       454.65770
# 2022-01-02                       443.35710
# ...                                    ...
# 2024-07-07                       502.43187
# 2024-07-14                       484.28010
# 2024-07-21                       378.19114
# 2024-07-28                       337.65740
# 2024-08-04                       141.35945
#
# [140 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
plt.figure('MONTHLY TREATED WATER PRODUCTION ')
plt.xlabel('DATETIME')
plt.ylabel('TREATED WATER PRODUCTION IN ML')
plt.plot(df)
# plt.figure(figsize=(1000, 600))
rcParams['figure.figsize'] = [70, 50] 
# plt.rcParams['figure.figsize'] = 12, 8

plt.show()

# %%
from pylab import rcParams
import matplotlib.pyplot as plt
import statsmodels.api as sm
rcParams['figure.figsize'] = 12, 8

decomposition = sm.tsa.seasonal_decompose(df['TREATED WATER PRODUCTION IN ML'], model='additive')


fig = decomposition.plot()

plt.show()

# %%
df.plot()
# Out:
# <Axes: xlabel='DATETIME'>

# %%
from statsmodels.tsa.stattools import adfuller
adfuller_result = adfuller(df, autolag='AIC')

print('ADF Statistic:', adfuller_result[0])

print('p-value:', adfuller_result[1])

print('Num of lags:', adfuller_result[2])

for key, value in adfuller_result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
print(f'Inference: The time series is {"non-" if adfuller_result[1]>= 0.05 else ""}stationary')
# Out:
# ADF Statistic: -1.7000671756004473
# p-value: 0.4310778663104838
# Num of lags: 2
# Critial Values:
#    1%, -3.479007355368944
# Critial Values:
#    5%, -2.8828782366015093
# Critial Values:
#    10%, -2.5781488587564603
# Inference: The time series is non-stationary

# %%
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(df['TREATED WATER PRODUCTION IN ML']); axes[0, 0].set_title('Original Series')
plot_acf((df['TREATED WATER PRODUCTION IN ML']), ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot((df['TREATED WATER PRODUCTION IN ML']).diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf((df['TREATED WATER PRODUCTION IN ML']).diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot((df['TREATED WATER PRODUCTION IN ML']).diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf((df['TREATED WATER PRODUCTION IN ML']).diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
from pmdarima.arima.utils import ndiffs
y = df['TREATED WATER PRODUCTION IN ML']

## Adf Test
# ndiffs(y, test='adf')  # 1

# KPSS test
ndiffs(y, test='kpss')  # 1

# PP test:
ndiffs(y, test='pp')  # 0
# Out:
# 0

# %%
df_diff=df.diff()
df_diff=df_diff.dropna()
adfuller_result = adfuller(df_diff, autolag='AIC')

print('ADF Statistic:', adfuller_result[0])

print('p-value:', adfuller_result[1])

print('Num of lags:', adfuller_result[2])

for key, value in adfuller_result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
print(f'Inference: The time series is {"non-" if adfuller_result[1]>= 0.05 else ""}stationary')
# Out:
# ADF Statistic: -12.488028094257274
# p-value: 2.988322873857365e-23
# Num of lags: 1
# Critial Values:
#    1%, -3.479007355368944
# Critial Values:
#    5%, -2.8828782366015093
# Critial Values:
#    10%, -2.5781488587564603
# Inference: The time series is stationary

# %%
# to find p
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf

# Plot partial autocorrelation
plt.rc("figure", figsize=(11,5))
nobs = len(df_diff['TREATED WATER PRODUCTION IN ML'])
max_lags = nobs // 2 - 1  # Ensure nlags is less than 50% of sample size
plot_pacf(df_diff['TREATED WATER PRODUCTION IN ML'], method='ywm', lags=max_lags)

plt.xlabel('Lags', fontsize=18)
plt.ylabel('Correlation', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Partial Autocorrelation Plot', fontsize=20)
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
selector = ar_select_order(df_diff['TREATED WATER PRODUCTION IN ML'], maxlag=2)
print(selector.ar_lags)
# Out:
# [1, 2]
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)

# %%
# to find q
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Plot autocorrelation
plt.rc("figure", figsize=(11,5))
plot_acf(df_diff['TREATED WATER PRODUCTION IN ML'])
plt.xlabel('Lags', fontsize=18)
plt.ylabel('Correlation', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Autocorrelation Plot', fontsize=20)
plt.tight_layout()
plt.show()

# %%
import pmdarima as pm
import numpy as np

# Use auto_arima to find the best MA(q) model
model = pm.auto_arima(df_diff, start_p=0, start_q=0, max_p=0, 
                      seasonal=False, stepwise=True, trace=True,
                      error_action='ignore', suppress_warnings=True, 
                      information_criterion='aic')

print(f"Optimal Order (q): {model.order[2]}")
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1563.808, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1524.049, Time=0.11 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1523.460, Time=0.10 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1525.206, Time=0.11 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=1525.350, Time=0.21 sec
#
# Best model:  ARIMA(0,0,2)(0,0,0)[0]
# Total fit time: 0.668 seconds
# Optimal Order (q): 2
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  139
# Model:               SARIMAX(0, 0, 2)   Log Likelihood                -758.730
# Date:                Tue, 27 Aug 2024   AIC                           1523.460
# Time:                        07:59:38   BIC                           1532.263
# Sample:                    12-12-2021   HQIC                          1527.037
#                          - 08-04-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6710      0.058    -11.522      0.000      -0.785      -0.557
# ma.L2          0.1705      0.080      2.123      0.034       0.013       0.328
# sigma2      3215.7333    264.641     12.151      0.000    2697.046    3734.420
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):               122.31
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                            -1.14
# Prob(H) (two-sided):                  0.57   Kurtosis:                         6.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# (0,0,0) - 139.180
# (0,1,0) -117.275
# (0,0,1) - 113.
# (0,1,1) -63.294
# (1,0,0) -89.982
# (1,1,0) -76.550
# (1,0,1) - 64.436
# (1,1,1) -63.796
# (2,0,0) - 70.610
# (2,0,1) - 64.641
# (2,1,0) - 66.213
# (2,1,1) - 65.386
from statsmodels.tsa.arima.model import ARIMA,ARIMAResults

# 0,1,0 ARIMA Model
model = ARIMA(df['TREATED WATER PRODUCTION IN ML'], order=(0,0,0))
model_fit = model.fit()
print(model_fit.summary())

from statsmodels.tsa.arima.model import ARIMA,ARIMAResults

# 0,1,0 ARIMA Model
model = ARIMA(df['TREATED WATER PRODUCTION IN ML'], order=(1,0,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:     TREATED WATER PRODUCTION IN ML   No. Observations:                  140
# Model:                                      ARIMA   Log Likelihood                -799.416
# Date:                            Tue, 27 Aug 2024   AIC                           1602.832
# Time:                                    07:59:43   BIC                           1608.715
# Sample:                                12-05-2021   HQIC                          1605.223
#                                      - 08-04-2024
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        477.9434      8.077     59.175      0.000     462.113     493.773
# sigma2      5335.7589    517.695     10.307      0.000    4321.095    6350.423
# ===================================================================================
# Ljung-Box (L1) (Q):                  33.28   Jarque-Bera (JB):               109.91
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.09   Skew:                            -1.47
# Prob(H) (two-sided):                  0.77   Kurtosis:                         6.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:     TREATED WATER PRODUCTION IN ML   No. Observations:                  140
# Model:                             ARIMA(1, 0, 1)   Log Likelihood                -764.302
# Date:                            Tue, 27 Aug 2024   AIC                           1536.605
# Time:                                    07:59:44   BIC                           1548.371
# Sample:                                12-05-2021   HQIC                          1541.386
#                                      - 08-04-2024
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        452.3048     34.439     13.134      0.000     384.806     519.804
# ar.L1          0.9399      0.037     25.229      0.000       0.867       1.013
# ma.L1         -0.5645      0.064     -8.863      0.000      -0.689      -0.440
# sigma2      3208.3272    259.358     12.370      0.000    2699.994    3716.660
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.82   Jarque-Bera (JB):               194.35
# Prob(Q):                              0.36   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.29   Skew:                            -1.54
# Prob(H) (two-sided):                  0.38   Kurtosis:                         7.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
import pmdarima as pm

# Automatically fit the best ARIMA model
model = pm.auto_arima(df, trace=True, suppress_warnings=True,max_p=3,max_q=2)

# Print the summary of the best model
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1529.064, Time=0.38 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1565.782, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1532.007, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1526.041, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1563.808, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1526.006, Time=0.23 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1527.240, Time=0.29 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1527.228, Time=0.20 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1525.427, Time=0.19 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1523.535, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1524.113, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1525.347, Time=0.19 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1524.100, Time=0.11 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 2.182 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  140
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -758.768
# Date:                Tue, 27 Aug 2024   AIC                           1523.535
# Time:                        07:59:46   BIC                           1532.339
# Sample:                    12-05-2021   HQIC                          1527.113
#                          - 08-04-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6704      0.058    -11.513      0.000      -0.785      -0.556
# ma.L2          0.1700      0.080      2.118      0.034       0.013       0.327
# sigma2      3215.8901    264.606     12.154      0.000    2697.272    3734.508
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):               122.05
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                            -1.14
# Prob(H) (two-sided):                  0.58   Kurtosis:                         6.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
df.tail(50)
# Out:
#             TREATED WATER PRODUCTION IN ML
# DATETIME
# 2023-08-27                      496.416332
# 2023-09-03                      541.225150
# 2023-09-10                      526.152770
# 2023-09-17                      487.078040
# 2023-09-24                      534.962970
# 2023-10-01                      482.121085
# 2023-10-08                      490.371810
# 2023-10-15                      437.964090
# 2023-10-22                      534.562540
# 2023-10-29                      419.633990
# 2023-11-05                      417.901610
# 2023-11-12                      487.003240
# 2023-11-19                      522.539970
# 2023-11-26                      525.467480
# 2023-12-03                      531.194920
# 2023-12-10                      514.291760
# 2023-12-17                      553.976610
# 2023-12-24                      454.919030
# 2023-12-31                      573.971070
# 2024-01-07                      301.772530
# 2024-01-14                      579.522010
# 2024-01-21                      570.505520
# 2024-01-28                      487.216690
# 2024-02-04                      575.651410
# 2024-02-11                      545.735322
# 2024-02-18                      559.595480
# 2024-02-25                      561.190040
# 2024-03-03                      565.410600
# 2024-03-10                      561.660919
# 2024-03-17                      573.903190
# 2024-03-24                      569.189860
# 2024-03-31                      556.370840
# 2024-04-07                      488.653260
# 2024-04-14                      535.207510
# 2024-04-21                      530.328921
# 2024-04-28                      560.083094
# 2024-05-05                      547.968030
# 2024-05-12                      560.759150
# 2024-05-19                      513.549361
# 2024-05-26                      545.517450
# 2024-06-02                      556.504740
# 2024-06-09                      541.301600
# 2024-06-16                      525.370160
# 2024-06-23                      550.242415
# 2024-06-30                      509.160640
# 2024-07-07                      502.431870
# 2024-07-14                      484.280100
# 2024-07-21                      378.191140
# 2024-07-28                      337.657400
# 2024-08-04                      141.359450

# %%
from statsmodels.tsa.stattools import adfuller
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima.model import ARIMA,ARIMAResults
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm
class TSA:
    def __init__(self,df):
        self.df = df
        
    def adf_test(self,valcol):
        """
        Pass in a time series and an optional title, returns an ADF report
        """
        result = adfuller(self.df[valcol].dropna(),autolag='AIC') # .dropna() handles differenced data
    
        labels = ['ADF test statistic','p-value','# lags used','# observations']
        out = pd.Series(result[0:4],index=labels)

        for key,val in result[4].items():
            out[f'critical value ({key})']=val
        
        print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
        if result[1] <= 0.05:
            print("Strong evidence against the null hypothesis")
            print("Reject the null hypothesis")
            print("Data has no unit root and is stationary")
            state = "Stationary"
        else:
            print("Weak evidence against the null hypothesis")
            print("Fail to reject the null hypothesis")
            print("Data has a unit root and is non-stationary")
            state = "Non-stationary"
        if state == "Stationary":
            return "Yes"
        else:
            return "No"
    def determine_ARIMA_order(self,valcol):
        stepwise_fit = auto_arima(self.df[valcol],start_p=1, start_q=1,max_p=3,max_q=3,trace=True,
                          error_action='ignore',   # we don't want to know if an order does not work
                          suppress_warnings=True,  # we don't want convergence warnings
                          stepwise=True)           # set to stepwise
        
#         print(stepwise_fit.summary())
# #         
        best_order = stepwise_fit.get_params().get('order')
#         best_order= (1,1,1)
        print('The best order is {}'.format(best_order))
        return best_order
    def fit_model(self,valcol):
#         if len(self.df[valcol]) > 70:
#         train = self.df[valcol][:len(self.df[valcol])-8]
#         test = self.df[valcol][len(self.df[valcol])-8:len(self.df[valcol])-4]
#         val = self.df[valcol][len(self.df[valcol])-4:]
        # Assuming 'valcol' is the column name containing the data
        train = self.df[self.df.index < '2024-01-07'][valcol]
        val = self.df[(self.df.index >= '2024-01-07') & (self.df.index <= '2024-05-05')][valcol]
        test = self.df[self.df.index > '2024-05-05'][valcol]


#             train = self.df[valcol][:len(self.df[valcol])-8]
#             test = self.df[valcol][len(self.df[valcol])-8:len(self.df[valcol])-4]
#             val = self.df[valcol][len(self.df[valcol])-4:]
        start = len(train)
        end = len(train)+len(test)-1
#             print('train : {}'.format(train))
#             print('test : {}'.format(test))
        print('start : {}'.format(start))
        print('end : {}'.format(end))
#         results = ARIMA(train,order=c1.determine_ARIMA_order(valcol)).fit()
        results = ARIMA(train,order=c1.determine_ARIMA_order(valcol),trend='t').fit()
        predictions = results.predict(start=start, end=end)
        predictions_val = results.predict(start=end+1, end=len(train)+len(test)+len(val)-1)
        error1 = mean_squared_error(test, predictions)
        error2 = rmse(test, predictions)
        error3 = mean_absolute_percentage_error(test,predictions)
        accuracy = (1-error3)*100
        print(f'MSE Error: {error1:11.10}')
        print(f'RMSE Error: {error2:11.10}')
        print(f'MAPE Error: {error3:11.10}')
        print(f'Accuracy: {accuracy:11.10}')
#         return start, len(test)
        model_results = {"Model":"ARIMA","Stationary": c1.adf_test(valcol),"X_train": str(len(train))+" Weeks", "X_test": str(len(test))+" Weeks", "X_validation": str(len(val))+" Weeks", "ARIMA_order": c1.determine_ARIMA_order(valcol), "MSE": error1,"RMSE": error2,"MAPE":error3, "Accuracy":((1-error3)*100).round(0)}
#         with open('TSA_AQI_model_result_new.json','a') as f:
#             f.write(str(model_results)+',')
#             f.close()
        return predictions_val
        
            
    def full_data_model(self,valcol):
        results = ARIMA(self.df[valcol],order=c1.determine_ARIMA_order(valcol)).fit()
#         if len(self.df[valcol]) > 70:
        fcast = results.predict(len(self.df), len(self.df)+3,typ='levels').round(2)
#         else:
#             fcast = results.predict(len(self.df), len(self.df)+3,typ='levels').round(2)
#         ax = self.df[valcol].plot(legend=True,figsize=(12,6))
#         fcast.plot(legend=True)
        print(fcast)
#         error_rmse = rmse(self.df[valcol],fcast[0:len(self.df)])
#         error_mse = mean_squared_error(self.df[valcol],fcast[0:len(self.df)])
        DF = pd.DataFrame(self.df[valcol])
        DF['Type'] = 'Actual'
#         DF = DF.reset_index()
        DF_fcast = pd.DataFrame(fcast)
        DF_fcast['Type'] = 'Predicted'
        DF_fcast = DF_fcast.rename(columns={'predicted_mean':valcol})
        final_DF = pd.concat([DF,DF_fcast])
        final_DF = final_DF.reset_index()
#         DF_fcast = DF_fcast.rename(columns={'predicted_mean':'Predicted', 'index':'DateTime'})
        DF_val = pd.DataFrame(c1.fit_model(valcol))
        DF_val = DF_val.reset_index()
        DF_val = DF_val.rename(columns={'index':'Date','predicted_mean':'Validation'})
        final_DF = final_DF.rename(columns={'index':'Date'})
        print(DF_val)
        print(final_DF)
#         final_DF =  final_DF.merge(DF_val, on='DateTime',how='outer')
        final_DF =  final_DF.merge(DF_val, on='Date',how='outer')
        final_DF['Date'] = final_DF['Date'].astype('str')
        print(final_DF)
        print(final_DF.tail(50))
        
c1 = TSA(df)
c1.adf_test("TREATED WATER PRODUCTION IN ML")
c1.determine_ARIMA_order("TREATED WATER PRODUCTION IN ML")
c1.fit_model("TREATED WATER PRODUCTION IN ML")
c1.full_data_model("TREATED WATER PRODUCTION IN ML")
# Out:
# ADF test statistic       -1.700067
# p-value                   0.431078
# # lags used               2.000000
# # observations          137.000000
# critical value (1%)      -3.479007
# critical value (5%)      -2.882878
# critical value (10%)     -2.578149
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1526.006, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1565.782, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1532.007, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1526.041, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1563.808, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1527.240, Time=0.26 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1527.228, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1525.427, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1527.163, Time=0.17 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1529.149, Time=0.37 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1523.535, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1524.113, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1525.347, Time=0.44 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=1525.281, Time=0.19 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1524.100, Time=0.17 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1527.244, Time=0.33 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 3.113 seconds
# The best order is (0, 1, 2)
# start : 109
# end : 121
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1526.006, Time=0.29 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1565.782, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1532.007, Time=0.19 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1526.041, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1563.808, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1527.240, Time=0.29 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1527.228, Time=0.23 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1525.427, Time=0.27 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1527.163, Time=0.20 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1529.149, Time=0.42 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1523.535, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1524.113, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1525.347, Time=0.24 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=1525.281, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1524.100, Time=0.12 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1527.244, Time=0.53 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 3.435 seconds
# The best order is (0, 1, 2)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# MSE Error:  18298.5212
# RMSE Error: 135.2720267
# MAPE Error: 0.3345599434
# Accuracy: 66.54400566
# ADF test statistic       -1.700067
# p-value                   0.431078
# # lags used               2.000000
# # observations          137.000000
# critical value (1%)      -3.479007
# critical value (5%)      -2.882878
# critical value (10%)     -2.578149
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1526.006, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1565.782, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1532.007, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1526.041, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1563.808, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1527.240, Time=0.32 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1527.228, Time=0.28 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1525.427, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1527.163, Time=0.21 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1529.149, Time=0.50 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1523.535, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1524.113, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1525.347, Time=0.22 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=1525.281, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1524.100, Time=0.12 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1527.244, Time=0.29 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 3.079 seconds
# The best order is (0, 1, 2)
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1526.006, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1565.782, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1532.007, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1526.041, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1563.808, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1527.240, Time=0.29 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1527.228, Time=0.19 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1525.427, Time=0.19 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1527.163, Time=0.18 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1529.149, Time=0.46 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1523.535, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1524.113, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1525.347, Time=0.19 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=1525.281, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1524.100, Time=0.12 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1527.244, Time=0.27 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 2.926 seconds
# The best order is (0, 1, 2)
# 2024-08-11    291.76
# 2024-08-18    248.55
# 2024-08-25    248.55
# 2024-09-01    248.55
# Freq: W-SUN, Name: predicted_mean, dtype: float64
# start : 109
# end : 121
# Performing stepwise search to minimize aic
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1526.006, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1565.782, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1532.007, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1526.041, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1563.808, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1527.240, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1527.228, Time=0.21 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1525.427, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1527.163, Time=0.21 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1529.149, Time=0.36 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1523.535, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1524.113, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1525.347, Time=0.24 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=1525.281, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1524.100, Time=0.12 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1527.244, Time=0.29 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 2.904 seconds
# The best order is (0, 1, 2)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# MSE Error:  18298.5212
# RMSE Error: 135.2720267
# MAPE Error: 0.3345599434
# Accuracy: 66.54400566
# ADF test statistic       -1.700067
# p-value                   0.431078
# # lags used               2.000000
# # observations          137.000000
# critical value (1%)      -3.479007
# critical value (5%)      -2.882878
# critical value (10%)     -2.578149
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1526.006, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1565.782, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1532.007, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1526.041, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1563.808, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1527.240, Time=0.31 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1527.228, Time=0.26 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1525.427, Time=0.25 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1527.163, Time=0.31 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1529.149, Time=0.46 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1523.535, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1524.113, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1525.347, Time=0.19 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=1525.281, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1524.100, Time=0.12 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1527.244, Time=0.32 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 3.311 seconds
# The best order is (0, 1, 2)
#          Date  Validation
# 0  2024-04-07  544.689854
# 1  2024-04-14  545.993389
# 2  2024-04-21  547.296925
# 3  2024-04-28  548.600460
# 4  2024-05-05  549.903995
# 5  2024-05-12  551.207530
# 6  2024-05-19  552.511065
# 7  2024-05-26  553.814600
# 8  2024-06-02  555.118136
# 9  2024-06-09  556.421671
# 10 2024-06-16  557.725206
# 11 2024-06-23  559.028741
# 12 2024-06-30  560.332276
# 13 2024-07-07  561.635812
# 14 2024-07-14  562.939347
# 15 2024-07-21  564.242882
# 16 2024-07-28  565.546417
# 17 2024-08-04  566.849952
#           Date  TREATED WATER PRODUCTION IN ML       Type
# 0   2021-12-05                       270.14856     Actual
# 1   2021-12-12                       447.63063     Actual
# 2   2021-12-19                       436.71396     Actual
# 3   2021-12-26                       454.65770     Actual
# 4   2022-01-02                       443.35710     Actual
# ..         ...                             ...        ...
# 139 2024-08-04                       141.35945     Actual
# 140 2024-08-11                       291.76000  Predicted
# 141 2024-08-18                       248.55000  Predicted
# 142 2024-08-25                       248.55000  Predicted
# 143 2024-09-01                       248.55000  Predicted
#
# [144 rows x 3 columns]
#            Date  TREATED WATER PRODUCTION IN ML       Type  Validation
# 0    2021-12-05                       270.14856     Actual         NaN
# 1    2021-12-12                       447.63063     Actual         NaN
# 2    2021-12-19                       436.71396     Actual         NaN
# 3    2021-12-26                       454.65770     Actual         NaN
# 4    2022-01-02                       443.35710     Actual         NaN
# ..          ...                             ...        ...         ...
# 139  2024-08-04                       141.35945     Actual  566.849952
# 140  2024-08-11                       291.76000  Predicted         NaN
# 141  2024-08-18                       248.55000  Predicted         NaN
# 142  2024-08-25                       248.55000  Predicted         NaN
# 143  2024-09-01                       248.55000  Predicted         NaN
#
# [144 rows x 4 columns]
#            Date  TREATED WATER PRODUCTION IN ML       Type  Validation
# 94   2023-09-24                      534.962970     Actual         NaN
# 95   2023-10-01                      482.121085     Actual         NaN
# 96   2023-10-08                      490.371810     Actual         NaN
# 97   2023-10-15                      437.964090     Actual         NaN
# 98   2023-10-22                      534.562540     Actual         NaN
# 99   2023-10-29                      419.633990     Actual         NaN
# 100  2023-11-05                      417.901610     Actual         NaN
# 101  2023-11-12                      487.003240     Actual         NaN
# 102  2023-11-19                      522.539970     Actual         NaN
# 103  2023-11-26                      525.467480     Actual         NaN
# 104  2023-12-03                      531.194920     Actual         NaN
# 105  2023-12-10                      514.291760     Actual         NaN
# 106  2023-12-17                      553.976610     Actual         NaN
# 107  2023-12-24                      454.919030     Actual         NaN
# 108  2023-12-31                      573.971070     Actual         NaN
# 109  2024-01-07                      301.772530     Actual         NaN
# 110  2024-01-14                      579.522010     Actual         NaN
# 111  2024-01-21                      570.505520     Actual         NaN
# 112  2024-01-28                      487.216690     Actual         NaN
# 113  2024-02-04                      575.651410     Actual         NaN
# 114  2024-02-11                      545.735322     Actual         NaN
# 115  2024-02-18                      559.595480     Actual         NaN
# 116  2024-02-25                      561.190040     Actual         NaN
# 117  2024-03-03                      565.410600     Actual         NaN
# 118  2024-03-10                      561.660919     Actual         NaN
# 119  2024-03-17                      573.903190     Actual         NaN
# 120  2024-03-24                      569.189860     Actual         NaN
# 121  2024-03-31                      556.370840     Actual         NaN
# 122  2024-04-07                      488.653260     Actual  544.689854
# 123  2024-04-14                      535.207510     Actual  545.993389
# 124  2024-04-21                      530.328921     Actual  547.296925
# 125  2024-04-28                      560.083094     Actual  548.600460
# 126  2024-05-05                      547.968030     Actual  549.903995
# 127  2024-05-12                      560.759150     Actual  551.207530
# 128  2024-05-19                      513.549361     Actual  552.511065
# 129  2024-05-26                      545.517450     Actual  553.814600
# 130  2024-06-02                      556.504740     Actual  555.118136
# 131  2024-06-09                      541.301600     Actual  556.421671
# 132  2024-06-16                      525.370160     Actual  557.725206
# 133  2024-06-23                      550.242415     Actual  559.028741
# 134  2024-06-30                      509.160640     Actual  560.332276
# 135  2024-07-07                      502.431870     Actual  561.635812
# 136  2024-07-14                      484.280100     Actual  562.939347
# 137  2024-07-21                      378.191140     Actual  564.242882
# 138  2024-07-28                      337.657400     Actual  565.546417
# 139  2024-08-04                      141.359450     Actual  566.849952
# 140  2024-08-11                      291.760000  Predicted         NaN
# 141  2024-08-18                      248.550000  Predicted         NaN
# 142  2024-08-25                      248.550000  Predicted         NaN
# 143  2024-09-01                      248.550000  Predicted         NaN

# %%
#  results.plot_diagnostics(figsize=(7,5))
#         plt.show()

#  print(final_DF)
#         plt.figure(figsize=(10,5))
#         plt.plot(DF["TREATED WATER PRODUCTION IN m3/h"],label='Actual');
#         plt.plot(DF_fcast["TREATED WATER PRODUCTION IN m3/h"],label='Predicted');
#         plt.legend(loc='best')

# %%
len(df)
# Out:
# 140

# %%
order=(0,1,1)

model=ARIMA(endog=df,order=order)
fit=model.fit()
fit.summary()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:     TREATED WATER PRODUCTION IN ML   No. Observations:                  140
# Model:                             ARIMA(0, 1, 1)   Log Likelihood                 -29.647
# Date:                            Mon, 26 Aug 2024   AIC                             63.294
# Time:                                    09:55:47   BIC                             69.163
# Sample:                                12-05-2021   HQIC                            65.679
#                                      - 08-04-2024
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6539      0.050    -13.167      0.000      -0.751      -0.557
# sigma2         0.0893      0.006     13.829      0.000       0.077       0.102
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.54   Jarque-Bera (JB):               118.50
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.20   Skew:                            -1.26
# Prob(H) (two-sided):                  0.53   Kurtosis:                         6.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
