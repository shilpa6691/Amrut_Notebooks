# %% [markdown]
# Basic cleaning done by Shilpa and Fathimath

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import datetime

# %%
data=pd.read_csv("Pattuvam_data_till_Aug_2024_corrected.csv")
# data

# %% [markdown]
# ## Making Standardised Date Format

# %%
from dateutil import parser
import pandas as pd

def standardize_date_format(date_str):
    try:
        # Use dateutil's parser to automatically recognize and convert various date formats
        date_obj = parser.parse(date_str)
        # Return the date in DD/MM/YYYY format
        return date_obj.strftime('%d/%m/%Y')
    except (ValueError, TypeError):
        # Handle cases where date_str is not a recognizable date
        return 'Unknown'

# Assuming you have a DataFrame named data with a 'DATE' column
data['Standardized_Date'] = data['DATE'].apply(standardize_date_format)

# print("DataFrame with standardized dates:")
# data

# %% [markdown]
# ## Making Standardised Time Format

# %%
### For time standardisation

def standardize_time(time_str):
 
    time_str = time_str.replace(' ', ':')     #For Replacing the spaces with colons
    
    
        #For cases where time is not in HH:MM format
        
    if len(time_str) == 1:  # Single digit hour
        time_str = f'0{time_str}:00'
    elif len(time_str) == 2:  # Only hour 
        time_str = f'{time_str}:00'
    elif len(time_str) == 4:  # Format like HHMM
        time_str = f'{time_str[:2]}:{time_str[2:]}'
    elif len(time_str) == 5 and ':' not in time_str:  # Format like HHMM
        time_str = f'{time_str[:2]}:{time_str[2:]}'
    
    # Convert to datetime and format as HH:MM
    try:
        return pd.to_datetime(time_str, format='%H:%M', errors='coerce').strftime('%H:%M')
    except ValueError:
        return None  # Return None for unparseable formats

# Apply the function to the TIME column
data['STANDARDIZED_TIME'] = data['TIME'].apply(standardize_time)

# %%
data.drop(index=range(2136, 2160), inplace=True) #These indexes shows 31/06/2024 data where June month contains only 30 days

# %%
data['Standardized_Date'] = data['Standardized_Date'].str.replace('2922', '2022')
data['Standardized_Date'] = data['Standardized_Date'].str.replace('2032', '2022')
data['Standardized_Date'] = data['Standardized_Date'].str.replace('2044', '2022')

# %%
data['Standardized_Date'] = pd.to_datetime(data['Standardized_Date'], format='DD/MM/YYYY',errors='coerce')

# %%
data.to_csv('corrected_date_and_time.csv',index=False)

# %% [raw]
# In this csv file some special characters are found in some of the column values and that cleaning is done manualy in the csv file.
# So the final csv file after cleaning all the special characters is All_Errors_Corrected.csv

# %% [markdown]
# # Cleaning of "REMARKS" and "	Standardized_Date" column

# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('All_Errors_Corrected.csv',parse_dates=['Standardized_Date'])
data.head()
# Out:
#   Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 0        2024-08-01              1:00                 2561.58
# 1        2024-08-01              2:00                 2510.71
# 2        2024-08-01              3:00                 2489.32
# 3        2024-08-01              4:00                 2444.78
# 4        2024-08-01              5:00                 2417.47
#
#    CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 0                             2.32                        1996.36
# 1                             2.49                        1984.73
# 2                             2.71                        1998.56
# 3                             2.79                        1972.01
# 4                             2.99                        1945.42
#
#    TREATED WATER PRODUCTION IN m3/h REMARKS
# 0                           2479.10     NaN
# 1                           2429.87     NaN
# 2                           2409.16     NaN
# 3                           2366.06     NaN
# 4                           2339.63     NaN

# %%
data.loc[19265]
# Out:
# Standardized_Date                   2022-07-13 00:00:00
# STANDARDIZED_TIME                                 17:00
# RAW WATER FLOW IN m3/h                          2953.63
# CLEAR WATER SUMP LEVEL IN Meter                    2.65
# CLEAR WATER PUMPING FLOW m3/h                   2718.72
# TREATED WATER PRODUCTION IN m3/h                2845.81
# REMARKS                                             NaN
# Name: 19265, dtype: object

# %%
# Correcting issue of 08-2022
data[data['Standardized_Date']=='2022-08-31']
# at index 18217 repetition started and ends at 18960
data.iloc[18216:18300]
data = data.drop(data.index[18217:18961])
data = data.reset_index(drop=True)
data.shape
# data[data['Standardized_Date']=='2022-08-31']
 
# # correcting the date where the two hours where misplaced
data[data['Standardized_Date']=='2022-08-20']
data.iloc[17927:17929]
# Replace the dates at indices 17927 and 17929 with the date from index 17926
data.loc[[17927, 17929], 'Standardized_Date'] = data.loc[17926,'Standardized_Date']
data.loc[[17928], 'STANDARDIZED_TIME'] = '1:00'
 
# # correcting date 2023-10-09 which was misplaced as 2023-10-10 
data[data['Standardized_Date']=='2023-10-11']
data.iloc[7440:7464]
# Replace the date in the column for the range of indices 7440 to 7464
data.loc[7440:7463, 'Standardized_Date'] = pd.Timestamp('2023-10-09')
 
# # 2023-11-09 is misplaced as 2023 -11-10 and 2023-11-10 is misplaced as 2023 -11-11
data[data['Standardized_Date']=='2023-11-10']
data.iloc[6720:6743]
data.loc[6720:6743, 'Standardized_Date'] = pd.Timestamp('2023-11-09')
data[data['Standardized_Date']=='2023-11-11']
data.iloc[6744:6767]
data.loc[6744:6767, 'Standardized_Date'] = pd.Timestamp('2023-11-10')
 
# # 2022-03-28 *48 since 2022 -05-28 is misplaced as 2022-03-2028
data[data['Standardized_Date']=='2022-03-28']
data.iloc[21790:21805]
# Replace the date in the column for the range of indices 20330 to 20354
data.loc[20329:20352, 'Standardized_Date'] = pd.Timestamp('2022-05-28')
 
# # 2022-05-16 (*25) since the 0:00 of  2022-05-15 was given this date,2023-05-14 the 0:00 of 2023-05-13 was given this date, the 0:00 of  2022-06-15 was given date 2022-06-16,same issue in 2023-01-07,same at 2022-07-16,same at 2022-12-07,same at 2022-04-16,same at 2022-12-01,same at 2022-03-16
# Loop through the DataFrame and check rows where time is '0:00'
 
for idx in data.index:
    if data.loc[idx, 'STANDARDIZED_TIME'] == '0:00':
        # Check the previous row's date and time
        if idx > 0:  # Ensure we are not checking the first row
            prev_date = data.loc[idx - 1, 'Standardized_Date']
            prev_time = data.loc[idx - 1, 'STANDARDIZED_TIME']
            # If the previous row's time is '23:00' and the dates are different
            if (prev_time == '23:00') and (prev_date != data.loc[idx, 'Standardized_Date']):
                # Reassign the current row's date to the previous date
                data.loc[idx, 'Standardized_Date'] = prev_date
# Dropping the error row with index 14544
data = data.drop(index=14544)
# Reset the index and drop the old index
data = data.reset_index(drop=True)
 
data[data['Standardized_Date']=='2022-08-28']
# Change the time at index 18126 to '7:00'
data.loc[18126, 'STANDARDIZED_TIME'] = '7:00'
 
#  2023-02-06 was also given to 3:00 of 2022-02-06
data[data['Standardized_Date']=='2022-02-06']
data.iloc[22005:22015]
data.loc[22009, 'Standardized_Date'] = pd.Timestamp('2022-02-06')
data.loc[22010, 'Standardized_Date'] = pd.Timestamp('2022-02-06')
 
# instead of 2023-08-10 the date 2023-10-08 is given at 20:00
data[data['Standardized_Date']=='2023-10-08']
data.loc[12619, 'Standardized_Date'] = pd.Timestamp('2023-08-10')
 
# 2022-06-04 was placed at 1:00 of 2022-07-04
data[data['Standardized_Date']=='2022-06-04']
data.loc[18288, 'Standardized_Date'] = pd.Timestamp('2022-07-04')
 
# 2023-03-20 at 2:00 was placed instead of 2023-03-21
data[data['Standardized_Date']=='2023-03-20']
data.loc[12121, 'Standardized_Date'] = pd.Timestamp('2023-03-21')
 
data[data['Standardized_Date']=='2023-12-03']
data.loc[11912, 'Standardized_Date'] = pd.Timestamp('2023-03-12')

# %%
# data.to_csv('data_with_corrected_date.csv',index=False)

# %%
data['Standardized_Date'].min()
# Out:
# Timestamp('2021-12-01 00:00:00')

# %%
data['Standardized_Date'].nunique()
# Out:
# 1002

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24048 entries, 0 to 24047
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Standardized_Date                 24048 non-null  datetime64[ns]
#  1   STANDARDIZED_TIME                 24048 non-null  object
#  2   RAW WATER FLOW IN m3/h            23991 non-null  float64
#  3   CLEAR WATER SUMP LEVEL IN Meter   23955 non-null  float64
#  4   CLEAR WATER PUMPING FLOW m3/h     24020 non-null  float64
#  5   TREATED WATER PRODUCTION IN m3/h  24047 non-null  float64
#  6   REMARKS                           175 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 1.3+ MB

# %%
data[data.Standardized_Date=='2022-09-05']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 16848        2022-09-05              1:00                 2298.65
# 16849        2022-09-05              2:00                 2289.09
# 16850        2022-09-05              3:00                 2278.67
# 16851        2022-09-05              4:00                 2298.76
# 16852        2022-09-05              5:00                 2287.43
# 16853        2022-09-05              6:00                 3308.44
# 16854        2022-09-05              7:00                 3304.69
# 16855        2022-09-05              8:00                 3307.21
# 16856        2022-09-05              9:00                 3294.69
# 16857        2022-09-05             10:00                 3296.02
# 16858        2022-09-05             11:00                 3298.89
# 16859        2022-09-05             12:00                 3308.49
# 16860        2022-09-05             13:00                 3306.56
# 16861        2022-09-05             14:00                 3244.46
# 16862        2022-09-05             15:00                 3247.73
# 16863        2022-09-05             16:00                 3242.83
# 16864        2022-09-05             17:00                 3245.73
# 16865        2022-09-05             18:00                 3248.76
# 16866        2022-09-05             19:00                 3257.59
# 16867        2022-09-05             20:00                 3245.82
# 16868        2022-09-05             21:00                 3245.89
# 16869        2022-09-05             22:00                 3265.82
# 16870        2022-09-05             23:00                 3262.82
# 16871        2022-09-05              0:00                 3259.03
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 16848                             4.00                        2817.32
# 16849                             3.57                        2798.25
# 16850                             3.13                        2789.12
# 16851                             2.70                        2788.07
# 16852                             2.29                        2790.53
# 16853                             2.14                        2789.44
# 16854                             2.17                        2754.44
# 16855                             2.15                        2761.12
# 16856                             2.28                        2724.95
# 16857                             2.39                        2767.46
# 16858                             2.46                        2776.63
# 16859                             2.45                        2781.86
# 16860                             2.43                        2777.76
# 16861                             2.36                        2760.11
# 16862                             2.26                        2774.78
# 16863                             2.23                        2761.73
# 16864                             2.21                        2750.28
# 16865                             2.22                        2759.43
# 16866                             2.27                        2761.63
# 16867                             2.31                        2750.84
# 16868                             2.33                        2754.67
# 16869                             2.36                        2765.23
# 16870                             2.54                        2777.08
# 16871                             2.75                        2780.37
#
#        TREATED WATER PRODUCTION IN m3/h REMARK
# 23552                           3182.33     NaN
# 23553                           3178.21     NaN
# 23554                           3195.76     NaN
# 23555                           3188.53     NaN
# 23556                           3190.59     NaN
# 23557                           3183.37     NaN
# 23558                           3179.23     NaN
# 23559                           3183.37     NaN
# 23560                           3196.80     NaN
# 23561                           3181.30     NaN
# 23562                           3185.44     NaN
# 23563                           3180.27     NaN
# 23564                           3178.21     NaN
# 23565                              0.00     NaN

# %%
data.loc[23001:23003]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 23001        2022-01-19             10:00                 3587.37
# 23002        2022-01-19             11:00                 3528.56
# 23003        2022-01-19             12:00                 3568.53
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 23001                             2.11                        2763.92
# 23002                             2.38                        2735.78
# 23003                             2.77                        2761.56
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS
# 23001                           3471.86     NaN
# 23002                           3414.94     NaN
# 23003                           3453.62     NaN

# %% [markdown]
# ### Remarks column correction

# %%
data.REMARKS.unique()
# Out:
# array([nan, 'Intake pumping well cleaning', 'power failure at intake',
#        'power failur at intake and wtp',
#        'Pumping stopped due to power failure at intake',
#        'Pumping stopped due to maintanance work at WTP and Intake',
#        'Pumping stopped for maintanance work & NHAI work.',
#        'RW pumping stopped', 'Power failure @ intake',
#        'Raw Water Reading not available due to PLC complaint.',
#        'power failure at 7.28 to 7.36 pm',
#        'Distribution line maintanance', 'Permitted power failure.',
#        'power failure', 'channel cieaning',
#        'stopped due to intake backwash', 'intake back wash',
#        'inlet chamber cleaning', 'power failure at wtp 6.03 to6.40am',
#        'Pumping stopped due to pipe line maintanance at taliparamba',
#        'power failur', 'Gravity line air valve maintenance',
#        'stopped for maintanance', 'power failuire at intake',
#        'power failed @9.45 to 2.25', '3', 'distribution line maintanance',
#        'Pumping Stoped Due to permitted Power failure at intake', '1',
#        'voltage fluctation at intake', 'Pumping stopped due to',
#        'Intake chamber cleaning', 'pumping sopped due to inake',
#        'chamber cleaning', 'pumping started', 'intake chamber cleaning',
#        'under voltage', 'intake backwash', 'Pumping Stoped due to intake',
#        'Sump Level Low', 'Pumping Stopped due to intake',
#        'Pumping Stoped due to Intake',
#        'permitted power failure at Intake', 'Power Failure at Intake',
#        'Pipe line broken at Taliparamba', 'Power failure at WTP',
#        'Power failure at Intake', 'Power failure at intake',
#        'POWER FAILURE', 'Power failure at intakeand WTP',
#        'permitted power failure', 'maintenance at Thaliparamba',
#        'maintenance work at Intake', 'informed power failure at',
#        'intake', 'Maintenance Work at', 'Intake', 'Power failure',
#        'PERMITTED POWER', 'FAILURE AT WTP', 'TWR Tank cleaning',
#        'Energy Auditing', 'Power Failure at intake', 'Power Failure'],
#       dtype=object)

# %%
data['REMARKS'] = data['REMARKS'].str.lower()
Rem = data.REMARKS.value_counts().reset_index()
# Rem.index = Rem.index.lower
Rem
# Out:
#                                                 index  REMARKS
# 0                                   twr tank cleaning       49
# 1                                       power failure       17
# 2                             power failure at intake       13
# 3                             intake chamber cleaning       11
# 4                              pumping stopped due to       11
# 5                                      sump level low        5
# 6                        pumping stoped due to intake        4
# 7                       distribution line maintanance        4
# 8                                                   1        3
# 9                                              intake        3
# 10                               power failure at wtp        3
# 11  pumping stopped due to pipe line maintanance a...        2
# 12                                maintenance work at        2
# 13                            permitted power failure        2
# 14  pumping stoped due to permitted power failure ...        2
# 15                                                  3        2
# 16                       intake pumping well cleaning        2
# 17                             inlet chamber cleaning        2
# 18     pumping stopped due to power failure at intake        2
# 19  pumping stopped due to maintanance work at wtp...        2
# 20  raw water reading not available due to plc com...        2
# 21  pumping stopped for maintanance work & nhai work.        2
# 22                     power failure at intakeand wtp        1
# 23                             power failure @ intake        1
# 24                      pumping stopped due to intake        1
# 25                  permitted power failure at intake        1
# 26                    pipe line broken at taliparamba        1
# 27                                 rw pumping stopped        1
# 28                 power failure at wtp 6.03 to6.40am        1
# 29                         maintenance work at intake        1
# 30                          informed power failure at        1
# 31                                    permitted power        1
# 32                                     failure at wtp        1
# 33                     power failur at intake and wtp        1
# 34                        maintenance at thaliparamba        1
# 35                                    intake backwash        1
# 36                                      under voltage        1
# 37                                    pumping started        1
# 38                                   chamber cleaning        1
# 39                        pumping sopped due to inake        1
# 40                   power failure at 7.28 to 7.36 pm        1
# 41                           permitted power failure.        1
# 42                       voltage fluctation at intake        1
# 43                                   channel cieaning        1
# 44                     stopped due to intake backwash        1
# 45                                   intake back wash        1
# 46                         power failed @9.45 to 2.25        1
# 47                           power failuire at intake        1
# 48                            stopped for maintanance        1
# 49                 gravity line air valve maintenance        1
# 50                                       power failur        1
# 51                                    energy auditing        1

# %%
data[data['REMARKS']=='maintenance work at']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 21952        2022-02-03             17:00                     0.0
# 22187        2022-02-13             12:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 21952                             2.40                            0.0
# 22187                             3.08                            0.0
#
#        TREATED WATER PRODUCTION IN m3/h              REMARKS
# 21952                               0.0  maintenance work at
# 22187                               0.0  maintenance work at

# %%
## REMARKS
#22697	2022-02-03	17:00	0.0	2.40	0.0	0.0	maintenance work at 
#22698	2022-02-03	18:00	0.0	2.09	0.0	0.0	intake

indices_maint = list(range(21952, 21954)) + \
          list(range(22187, 22189))
data.loc[indices_maint,'REMARKS'] = 'maintanance work at intake'
rows = data.loc[indices_maint]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 21952        2022-02-03             17:00                     0.0
# 21953        2022-02-03             18:00                     0.0
# 22187        2022-02-13             12:00                     0.0
# 22188        2022-02-13             13:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 21952                             2.40                            0.0
# 21953                             2.09                            0.0
# 22187                             3.08                            0.0
# 22188                             3.05                            0.0
#
#        TREATED WATER PRODUCTION IN m3/h                     REMARKS
# 21952                               0.0  maintanance work at intake
# 21953                               0.0  maintanance work at intake
# 22187                               0.0  maintanance work at intake
# 22188                               0.0  maintanance work at intake

# %%
list1 = ['1','3','pumping started','power failure at 7.28 to 7.36 pm','power failure at wtp 6.03 to6.40am']
for i in range(len(data)):
    if data.loc[i,'REMARKS'] in list1:
        data.loc[i,'REMARKS'] = np.nan

# %%
data[(data['REMARKS']=='pumping stoped due to intake')|(data['REMARKS']=='pumping sopped due to inake')|(data['REMARKS']=='pumping stopped due to intake')]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 17217        2022-09-20             10:00                     0.0
# 18294        2022-07-04              7:00                     0.0
# 18309        2022-07-04             22:00                     0.0
# 18328        2022-07-05             17:00                     0.0
# 18341        2022-07-06              6:00                     0.0
# 18366        2022-07-07              7:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 17217                             3.38                           0.00
# 18294                             2.94                           0.00
# 18309                             2.65                        1848.71
# 18328                             3.67                           0.00
# 18341                             3.05                           0.00
# 18366                             2.85                           0.00
#
#        TREATED WATER PRODUCTION IN m3/h                        REMARKS
# 17217                               0.0    pumping sopped due to inake
# 18294                               0.0   pumping stoped due to intake
# 18309                               0.0  pumping stopped due to intake
# 18328                               0.0   pumping stoped due to intake
# 18341                               0.0   pumping stoped due to intake
# 18366                               0.0   pumping stoped due to intake

# %%
## REMARKS
# 19039	2022-07-04	7:00	0.0	2.94	0.00	0.0	pumping stoped due to intake
# 19040	2022-07-04	8:00	0.0	2.64	0.00	0.0	sump level low

indices_sump = list(range(18294, 18296)) + \
          list(range(18309, 18311)) + \
          list(range(18328, 18330)) + \
          list(range(18341, 18343)) + \
          list(range(18366, 18368))
data.loc[indices_sump,'REMARKS'] = 'intake sump level low'
rows = data.loc[indices_sump]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 18294        2022-07-04              7:00                     0.0
# 18295        2022-07-04              8:00                     0.0
# 18309        2022-07-04             22:00                     0.0
# 18310        2022-07-04             23:00                     0.0
# 18328        2022-07-05             17:00                     0.0
# 18329        2022-07-05             18:00                     0.0
# 18341        2022-07-06              6:00                     0.0
# 18342        2022-07-06              7:00                     0.0
# 18366        2022-07-07              7:00                     0.0
# 18367        2022-07-07              8:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 18294                             2.94                           0.00
# 18295                             2.64                           0.00
# 18309                             2.65                        1848.71
# 18310                             2.02                           0.00
# 18328                             3.67                           0.00
# 18329                             3.54                           0.00
# 18341                             3.05                           0.00
# 18342                             2.92                           0.00
# 18366                             2.85                           0.00
# 18367                             2.79                           0.00
#
#        TREATED WATER PRODUCTION IN m3/h                REMARKS
# 18294                               0.0  intake sump level low
# 18295                               0.0  intake sump level low
# 18309                               0.0  intake sump level low
# 18310                               0.0  intake sump level low
# 18328                               0.0  intake sump level low
# 18329                               0.0  intake sump level low
# 18341                               0.0  intake sump level low
# 18342                               0.0  intake sump level low
# 18366                               0.0  intake sump level low
# 18367                               0.0  intake sump level low

# %%
## REMARKS
# 17218	2022-09-20	10:00	0.0	3.38	0.0	0.0	pumping sopped due to inake
# 17219	2022-09-20	11:00	0.0	3.34	0.0	0.0	chamber cleaning

indices_chamber = list(range(17217, 17219))
data.loc[indices_chamber,'REMARKS'] = 'intake chamber cleaning'
rows = data.loc[indices_chamber]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 17217        2022-09-20             10:00                     0.0
# 17218        2022-09-20             11:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 17217                             3.38                            0.0
# 17218                             3.34                            0.0
#
#        TREATED WATER PRODUCTION IN m3/h                  REMARKS
# 17217                               0.0  intake chamber cleaning
# 17218                               0.0  intake chamber cleaning

# %%
data[data.REMARKS=='pumping stopped due to']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 16256        2022-10-11              9:00                    0.00
# 17264        2022-09-22              9:00                 3284.23
# 17913        2022-08-19             10:00                    0.00
# 17937        2022-08-20             10:00                    0.00
# 17959        2022-08-21              8:00                 3239.05
# 17986        2022-08-22             11:00                    0.00
# 18033        2022-08-24             10:00                    0.00
# 18057        2022-08-25             10:00                    0.00
# 19289        2022-06-14             18:00                    0.00
# 21069        2022-04-27             22:00                     NaN
# 21103        2022-04-29              8:00                    0.00
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 16256                             2.72                           0.00
# 17264                             3.38                        2774.03
# 17913                             3.46                           0.00
# 17937                             2.72                           0.00
# 17959                             3.41                        2807.96
# 17986                             3.19                           0.00
# 18033                             3.01                           0.00
# 18057                             3.35                           0.00
# 19289                             3.12                           0.00
# 21069                              NaN                            NaN
# 21103                             2.00                           0.00
#
#        TREATED WATER PRODUCTION IN m3/h                 REMARKS
# 16256                              0.00  pumping stopped due to
# 17264                           3178.48  pumping stopped due to
# 17913                              0.00  pumping stopped due to
# 17937                              0.00  pumping stopped due to
# 17959                           3134.75  pumping stopped due to
# 17986                              0.00  pumping stopped due to
# 18033                              0.00  pumping stopped due to
# 18057                              0.00  pumping stopped due to
# 19289                              0.00  pumping stopped due to
# 21069                              0.00  pumping stopped due to
# 21103                              0.00  pumping stopped due to

# %%
## REMARKS
# 16257	2022-10-11	9:00	0.00	2.72	0.00	0.00	pumping stopped due to
# 16258	2022-10-11	10:00	0.00	2.66	0.00	0.00	intake chamber cleaning

indices_chamber = list(range(16256, 16258)) + \
          list(range(17264, 17266)) + \
          list(range(17913, 17915)) + \
          list(range(17937, 17939)) + \
          list(range(17959, 17961)) + \
          list(range(17986, 17988)) + \
          list(range(18033, 18035)) + \
          list(range(18057, 18059)) 
#           list(range(19289, 19291)) + \
#           list(range(21069, 21071)) + \
#           list(range(21103, 21105)) 
data.loc[indices_chamber,'REMARKS'] = 'intake chamber cleaning'
rows = data.loc[indices_chamber]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 16256        2022-10-11              9:00                    0.00
# 16257        2022-10-11             10:00                    0.00
# 17264        2022-09-22              9:00                 3284.23
# 17265        2022-09-22             10:00                    0.00
# 17913        2022-08-19             10:00                    0.00
# 17914        2022-08-19             11:00                    0.00
# 17937        2022-08-20             10:00                    0.00
# 17938        2022-08-20             11:00                    0.00
# 17959        2022-08-21              8:00                 3239.05
# 17960        2022-08-21              9:00                    0.00
# 17986        2022-08-22             11:00                    0.00
# 17987        2022-08-22             12:00                    0.00
# 18033        2022-08-24             10:00                    0.00
# 18034        2022-08-24             11:00                    0.00
# 18057        2022-08-25             10:00                    0.00
# 18058        2022-08-25             11:00                    0.00
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 16256                             2.72                           0.00
# 16257                             2.66                           0.00
# 17264                             3.38                        2774.03
# 17265                             3.37                           0.00
# 17913                             3.46                           0.00
# 17914                             3.37                           0.00
# 17937                             2.72                           0.00
# 17938                             2.61                           0.00
# 17959                             3.41                        2807.96
# 17960                             3.41                           0.00
# 17986                             3.19                           0.00
# 17987                             3.06                           0.00
# 18033                             3.01                           0.00
# 18034                             2.76                           0.00
# 18057                             3.35                           0.00
# 18058                             3.13                           0.00
#
#        TREATED WATER PRODUCTION IN m3/h                  REMARKS
# 16256                              0.00  intake chamber cleaning
# 16257                              0.00  intake chamber cleaning
# 17264                           3178.48  intake chamber cleaning
# 17265                              0.00  intake chamber cleaning
# 17913                              0.00  intake chamber cleaning
# 17914                              0.00  intake chamber cleaning
# 17937                              0.00  intake chamber cleaning
# 17938                              0.00  intake chamber cleaning
# 17959                           3134.75  intake chamber cleaning
# 17960                              0.00  intake chamber cleaning
# 17986                              0.00  intake chamber cleaning
# 17987                              0.00  intake chamber cleaning
# 18033                              0.00  intake chamber cleaning
# 18034                              0.00  intake chamber cleaning
# 18057                              0.00  intake chamber cleaning
# 18058                              0.00  intake chamber cleaning

# %%
## REMARKS
# 20034	2022-06-14	18:00	0.0	3.12	0.0	0.0	pumping stopped due to
# 20035	2022-06-14	19:00	0.0	3.10	0.0	0.0	pipe line broken at taliparamba
# 21814	2022-04-27	22:00	NaN	NaN	NaN	0.0	pumping stopped due to
# 21815	2022-04-27	23:00	NaN	NaN	NaN	0.0	maintenance at thaliparamba

indices_thaliparambu =list(range(19289, 19291))
data.loc[indices_thaliparambu,'REMARKS'] = 'pipe line broken at Thaliparamba'

indices_thaliparambu =list(range(21069, 21071))
data.loc[indices_thaliparambu,'REMARKS'] = 'maintanance at Thaliparamba'


## REMARKS
# 21848	2022-04-29	8:00	0.0	2.0	0.0	0.0	pumping stopped due to
# 21849	2022-04-29	9:00	0.0	2.0	0.0	0.0	maintenance work at intake

indices_maintain =list(range(21103, 21105))
data.loc[indices_maintain,'REMARKS'] = 'maintanance work at intake'
rows = data.loc[indices_maintain]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 21103        2022-04-29              8:00                     0.0
# 21104        2022-04-29              9:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 21103                              2.0                            0.0
# 21104                              2.0                            0.0
#
#        TREATED WATER PRODUCTION IN m3/h                     REMARKS
# 21103                               0.0  maintanance work at intake
# 21104                               0.0  maintanance work at intake

# %%
data[data.REMARKS=='power failed @9.45 to 2.25']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 13328        2023-02-09              9:00                 3532.62
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 13328                             2.93                        2787.92
#
#        TREATED WATER PRODUCTION IN m3/h                     REMARKS
# 13328                           3418.87  power failed @9.45 to 2.25

# %%
data.loc[13328,'REMARKS'] = np.nan
data.loc[13329,'REMARKS'] = 'power failure at intake and WTP'

# %%
data[data.REMARKS=='permitted power']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 22256        2022-02-16              9:00                 3604.19
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 22256                             3.33                        2781.45
#
#        TREATED WATER PRODUCTION IN m3/h          REMARKS
# 22256                           3488.14  permitted power

# %%
## REMARKS
# 23001	2022-02-16	9:00	3604.19	3.33	2781.45	3488.14	permitted power
# 23002	2022-02-16	10:00	0.00	0.00	0.00	0.00	failure at wtp

indices_wtp_power =list(range(22256, 22258)) 
data.loc[indices_wtp_power,'REMARKS'] = 'power failure at WTP'
data.loc[22256,'REMARKS'] = np.nan
rows = data.loc[indices_wtp_power]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 22256        2022-02-16              9:00                 3604.19
# 22257        2022-02-16             10:00                    0.00
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 22256                             3.33                        2781.45
# 22257                             0.00                           0.00
#
#        TREATED WATER PRODUCTION IN m3/h               REMARKS
# 22256                           3488.14                   NaN
# 22257                              0.00  power failure at WTP

# %%
data[data.REMARKS=='informed power failure at']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 21752        2022-03-26              9:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 21752                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h                    REMARKS
# 21752                               0.0  informed power failure at

# %%
## REMARKS
# 22497	2022-03-26	9:00	NaN	NaN	NaN	0.0	informed power failure at
# 22498	2022-03-26	10:00	NaN	NaN	NaN	0.0	intake

indices_intake_power = [21752,21753]
data.loc[indices_intake_power,'REMARKS'] = 'power failure at intake'
rows = data.loc[indices_intake_power]
rows
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 21752        2022-03-26              9:00                     NaN
# 21753        2022-03-26             10:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 21752                              NaN                            NaN
# 21753                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h                  REMARKS
# 21752                               0.0  power failure at intake
# 21753                               0.0  power failure at intake

# %%
data[data.REMARKS=='rw pumping stopped']
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 5173        2024-01-06             14:00                 1265.45
#
#       CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 5173                             3.92                            0.0
#
#       TREATED WATER PRODUCTION IN m3/h             REMARKS
# 5173                            1224.7  rw pumping stopped

# %%
data[5173:5175]
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 5173        2024-01-06             14:00                 1265.45
# 5174        2024-01-06             15:00                    0.00
#
#       CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 5173                             3.92                            0.0
# 5174                             3.81                            0.0
#
#       TREATED WATER PRODUCTION IN m3/h             REMARKS
# 5173                            1224.7  rw pumping stopped
# 5174                               0.0                 NaN

# %%
data[data.REMARKS=='power failure']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 9111         2023-06-17             16:00                     NaN
# 17654        2022-08-08             15:00                    0.00
# 17658        2022-08-08             19:00                    0.00
# 17752        2022-08-12             17:00                    0.00
# 19071        2022-06-05             16:00                    0.00
# 19751        2022-05-03              0:00                    0.00
# 20193        2022-05-22             10:00                 2475.82
# 20703        2022-04-12             16:00                    0.00
# 20731        2022-04-13             20:00                    0.00
# 20945        2022-04-22             18:00                 1224.45
# 21011        2022-04-25             12:00                    0.00
# 21033        2022-04-26             10:00                    0.00
# 22024        2022-02-06             17:00                 3660.16
# 22089        2022-02-09             10:00                    0.00
# 22209        2022-02-14             10:00                    0.00
# 23224        2022-01-28             17:00                 2523.84
# 23225        2022-01-28             18:00                    0.00
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 9111                               NaN                            NaN
# 17654                             2.91                           0.00
# 17658                             3.03                           0.00
# 17752                             2.38                           0.00
# 19071                             4.00                           0.00
# 19751                             2.26                        2741.36
# 20193                             3.92                        2842.36
# 20703                             0.00                           0.00
# 20731                             2.75                           0.00
# 20945                             3.35                           0.00
# 21011                             3.34                           0.00
# 21033                             1.89                           0.00
# 22024                             3.14                           0.00
# 22089                             3.25                           0.00
# 22209                             3.85                           0.00
# 23224                             3.85                           0.00
# 23225                             3.77                        1864.75
#
#        TREATED WATER PRODUCTION IN m3/h        REMARKS
# 9111                               0.00  power failure
# 17654                              0.00  power failure
# 17658                              0.00  power failure
# 17752                              0.00  power failure
# 19071                              0.00  power failure
# 19751                              0.00  power failure
# 20193                           2396.10  power failure
# 20703                              0.00  power failure
# 20731                              0.00  power failure
# 20945                           1185.02  power failure
# 21011                              0.00  power failure
# 21033                              0.00  power failure
# 22024                           3542.30  power failure
# 22089                              0.00  power failure
# 22209                              0.00  power failure
# 23224                           2442.57  power failure
# 23225                              0.00  power failure

# %%
# 20938	2022-05-22	10:00	2475.82	3.92	2842.36	2396.10	power failure	
data.loc[20193,'REMARKS'] = np.nan

# %%
data[5172:5195]
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 5172        2024-01-06             13:00                 1288.54
# 5173        2024-01-06             14:00                 1265.45
# 5174        2024-01-06             15:00                    0.00
# 5175        2024-01-06             16:00                    0.00
# 5176        2024-01-06             17:00                    0.00
# 5177        2024-01-06             18:00                    0.00
# 5178        2024-01-06             19:00                    0.00
# 5179        2024-01-06             20:00                    0.00
# 5180        2024-01-06             21:00                    0.00
# 5181        2024-01-06             22:00                    0.00
# 5182        2024-01-06             23:00                    0.00
# 5183        2024-01-06              0:00                    0.00
# 5184        2024-01-07              1:00                    0.00
# 5185        2024-01-07              2:00                    0.00
# 5186        2024-01-07              3:00                    0.00
# 5187        2024-01-07              4:00                 1216.67
# 5188        2024-01-07              5:00                 1211.33
# 5189        2024-01-07              6:00                 1223.07
# 5190        2024-01-07              7:00                 1209.81
# 5191        2024-01-07              8:00                 1229.58
# 5192        2024-01-07              9:00                 2429.07
# 5193        2024-01-07             10:00                 2416.00
# 5194        2024-01-07             11:00                 2505.76
#
#       CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 5172                             3.78                           0.00
# 5173                             3.92                           0.00
# 5174                             3.81                           0.00
# 5175                             3.70                           0.00
# 5176                             3.59                           0.00
# 5177                             3.47                           0.00
# 5178                             3.36                         915.10
# 5179                             3.01                         910.67
# 5180                             2.74                         902.91
# 5181                             2.28                           0.00
# 5182                             2.28                           0.00
# 5183                             2.30                           0.00
# 5184                             2.32                           0.00
# 5185                             2.34                           0.00
# 5186                             2.24                         900.70
# 5187                             1.63                         881.86
# 5188                             1.13                         878.65
# 5189                             1.10                         902.91
# 5190                             1.07                         905.21
# 5191                             1.15                         915.24
# 5192                             1.17                        1813.34
# 5193                             1.48                        1843.17
# 5194                             2.43                        1871.19
#
#       TREATED WATER PRODUCTION IN m3/h             REMARKS
# 5172                           1247.05                 NaN
# 5173                           1224.70  rw pumping stopped
# 5174                              0.00                 NaN
# 5175                              0.00                 NaN
# 5176                              0.00                 NaN
# 5177                              0.00                 NaN
# 5178                              0.00                 NaN
# 5179                              0.00                 NaN
# 5180                              0.00                 NaN
# 5181                              0.00                 NaN
# 5182                              0.00                 NaN
# 5183                              0.00                 NaN
# 5184                              0.00                 NaN
# 5185                              0.00                 NaN
# 5186                              0.00                 NaN
# 5187                           1177.49                 NaN
# 5188                           1172.33                 NaN
# 5189                           1183.69                 NaN
# 5190                           1170.85                 NaN
# 5191                           1189.99                 NaN
# 5192                           2350.85                 NaN
# 5193                           2338.20                 NaN
# 5194                           2425.07                 NaN

# %%
# 5173	2024-01-06	14:00	1265.45	3.92	0.00	1224.70	rw pumping stopped
data.loc[5173,'REMARKS'] = np.nan
data.loc[5174,'REMARKS'] = 'intake pumping stopped'

# %%
data['REMARKS'] = data['REMARKS'].str.lower()
Rem = data.REMARKS.value_counts().reset_index()
# Rem.index = Rem.index.lower
Rem
# Out:
#                                                 index  REMARKS
# 0                                   twr tank cleaning       49
# 1                             intake chamber cleaning       21
# 2                                       power failure       16
# 3                             power failure at intake       15
# 4                               intake sump level low       10
# 5                          maintanance work at intake        6
# 6                       distribution line maintanance        4
# 7                                power failure at wtp        4
# 8   pumping stopped due to pipe line maintanance a...        2
# 9                              inlet chamber cleaning        2
# 10                   pipe line broken at thaliparamba        2
# 11                       intake pumping well cleaning        2
# 12                            permitted power failure        2
# 13  raw water reading not available due to plc com...        2
# 14                        maintanance at thaliparamba        2
# 15  pumping stopped for maintanance work & nhai work.        2
# 16  pumping stopped due to maintanance work at wtp...        2
# 17     pumping stopped due to power failure at intake        2
# 18  pumping stoped due to permitted power failure ...        2
# 19                     power failure at intakeand wtp        1
# 20                  permitted power failure at intake        1
# 21                                    intake backwash        1
# 22                                      under voltage        1
# 23                 gravity line air valve maintenance        1
# 24                       voltage fluctation at intake        1
# 25                    power failure at intake and wtp        1
# 26                           power failuire at intake        1
# 27                            stopped for maintanance        1
# 28                                       power failur        1
# 29                                   intake back wash        1
# 30                     stopped due to intake backwash        1
# 31                                   channel cieaning        1
# 32                           permitted power failure.        1
# 33                             power failure @ intake        1
# 34                             intake pumping stopped        1
# 35                     power failur at intake and wtp        1
# 36                                    energy auditing        1

# %% [markdown]
# ## Categorize REMARKS column

# %%
df = data.copy()

# %%
def categorize_remarks(data):
    """
    Categorizes the remarks column based on specific conditions:
    1. 'Power Failure at Intake' if:
       - Contains 'intake' (case-insensitive)
       - Contains 'power' (case-insensitive)
       - Does not contain 'wtp' (case-insensitive)
    
    2. 'Power Failure at WTP' if:
       - Does not contain 'intake'
       - Contains 'power' (case-insensitive)
       - Contains 'wtp' (case-insensitive)
    """
    
    def categorize(row):
        remarks = row['REMARKS']
        raw_water = row['RAW WATER FLOW IN m3/h']
        clear_water_pumping = row['CLEAR WATER PUMPING FLOW m3/h']
        if pd.notna(remarks):
            remarks_lower = remarks.lower()
            if ('intake' in remarks_lower and ('power' in remarks_lower or 'failure' in remarks_lower) and 'wtp' not in remarks_lower) or (('power' in remarks_lower or 'failure' in remarks_lower) and 'wtp' not in remarks_lower and (raw_water == 0.0 or pd.isna(raw_water)) and not pd.isna(clear_water_pumping) and clear_water_pumping != 0.0):
                return 'Power Failure at Intake'
            elif ('intake' not in remarks_lower and ('power' in remarks_lower or 'failure' in remarks_lower) and 'wtp' in remarks_lower) or (('power' in remarks_lower or 'failure' in remarks_lower) and 'intake' not in remarks_lower and not pd.isna(raw_water) and raw_water !=0.0 and (clear_water_pumping == 0.0 or pd.isna(clear_water_pumping))):
                return 'Power Failure at WTP'
            elif ('intake' in remarks_lower and ('power' in remarks_lower or 'failure' in remarks_lower) and 'wtp' in remarks_lower) or ('intake' not in remarks_lower and 'wtp' not in remarks_lower and ('power' in remarks_lower or 'failure' in remarks_lower) and (raw_water == 0.0 or pd.isna(raw_water)) and (clear_water_pumping == 0.0 or pd.isna(clear_water_pumping))):
                return 'Power Failure at intake and WTP'
            elif (('cleaning' in remarks_lower or 'wash' in remarks_lower) and 'intake' in remarks_lower):
                return 'intake cleaning'
            elif 'maint' in remarks_lower and 'intake' in remarks_lower:
                return 'maintanance at intake'
            elif 'maint' in remarks_lower and 'thaliparamba' in remarks_lower or 'taliparamba' in remarks_lower:
                return 'maintanance at Thaliparamba'
            elif 'maint' in remarks_lower and 'distribution' in remarks_lower:
                return 'distribution line maintanance'
            elif 'maint' in remarks_lower:
                return 'maintanance'
#             elif 'intake sump level low' in remarks_lower:
#                 return 'intake sump level low'
#             elif 'energy auditing' in remarks_lower:
#                 return 'energy auditing'
#             elif 'issue at thaliparambu' in remarks_lower:
#                 return 'issue at thaliparambu'
            elif 'cleaning' in remarks_lower and ('twr' in remarks_lower or 'wtp' in remarks_lower):
                return 'WTP cleaning'
#             elif 'intake pumping stopped' in remarks_lower:
#                 return 'intake pumping stopped'
            elif 'plc complaint' in remarks_lower:
                return 'complaint at WTP'
            else:
                return remarks_lower
            
#         return ''

    # Apply the categorization function to each row
    data['remarks category'] = data.apply(categorize, axis=1)
    
    return data

# %%
df = categorize_remarks(df)
df
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 0            2024-08-01              1:00                 2561.58
# 1            2024-08-01              2:00                 2510.71
# 2            2024-08-01              3:00                 2489.32
# 3            2024-08-01              4:00                 2444.78
# 4            2024-08-01              5:00                 2417.47
# ...                 ...               ...                     ...
# 24043        2021-12-31             20:00                 2499.51
# 24044        2021-12-31             21:00                 2477.10
# 24045        2021-12-31             22:00                 2470.76
# 24046        2021-12-31             23:00                 2492.04
# 24047        2021-12-31              0:00                 2494.18
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 0                                 2.32                        1996.36
# 1                                 2.49                        1984.73
# 2                                 2.71                        1998.56
# 3                                 2.79                        1972.01
# 4                                 2.99                        1945.42
# ...                                ...                            ...
# 24043                             2.89                        1851.25
# 24044                             3.06                        1878.95
# 24045                             3.25                        1913.29
# 24046                             3.30                        1904.43
# 24047                             3.33                        1896.67
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 0                               2479.10     NaN             None
# 1                               2429.87     NaN             None
# 2                               2409.16     NaN             None
# 3                               2366.06     NaN             None
# 4                               2339.63     NaN             None
# ...                                 ...     ...              ...
# 24043                           2419.03     NaN             None
# 24044                           2397.34     NaN             None
# 24045                           2391.20     NaN             None
# 24046                           2411.80     NaN             None
# 24047                           2413.87     NaN             None
#
# [24048 rows x 8 columns]

# %%
# df[df['remarks category'].notna()]

# %%
# data[(data['REMARKS'].str.contains('intake', case=False)) & (data['REMARKS'].str.contains('power', case=False))&(data['REMARKS'].str.contains('wtp', case=False))]

# %%
# df[df['remarks category'].notna()].shape

# %%
df['remarks category'].value_counts()
# Out:
# WTP cleaning                        49
# intake cleaning                     26
# Power Failure at Intake             24
# Power Failure at intake and WTP     17
# intake sump level low               10
# maintanance at intake                8
# Power Failure at WTP                 8
# maintanance                          4
# distribution line maintanance        4
# maintanance at Thaliparamba          4
# pipe line broken at thaliparamba     2
# inlet chamber cleaning               2
# complaint at WTP                     2
# under voltage                        1
# voltage fluctation at intake         1
# channel cieaning                     1
# intake pumping stopped               1
# energy auditing                      1
# Name: remarks category, dtype: int64

# %%
df[df['remarks category']=='maintanance']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 5112         2024-01-04              1:00                    0.00
# 5113         2024-01-04              2:00                    0.00
# 11166        2023-04-11              7:00                 2510.35
# 12696        2023-08-14              1:00                    0.00
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 5112                               NaN                           0.00
# 5113                               NaN                           0.00
# 11166                             3.93                           0.00
# 12696                             1.06                        1856.25
#
#        TREATED WATER PRODUCTION IN m3/h  \
# 5112                               0.00
# 5113                               0.00
# 11166                           2429.52
# 12696                              0.00
#
#                                                  REMARKS remarks category
# 5112   pumping stopped for maintanance work & nhai work.      maintanance
# 5113   pumping stopped for maintanance work & nhai work.      maintanance
# 11166                 gravity line air valve maintenance      maintanance
# 12696                            stopped for maintanance      maintanance

# %%
df[df['remarks category'].isna()].REMARKS.nunique()
# Out:
# 0

# %%
remain_list = list(df[df['remarks category'].isna()].REMARKS.unique())
remain_list
# Out:
# [nan]

# %% [markdown]
# ## Filling 'remarks category' column

# %%
# Function to fill NaN values in 'remarks category' based on the conditions
def fill_remarks_category(df):
    previous_remark = None
#     remarks_flag=False
    for i in range(len(df)):
        current_remark = df.loc[i, 'remarks category']
        raw_water_flow = df.loc[i, 'RAW WATER FLOW IN m3/h']
        clear_water_pumping_flow = df.loc[i, 'CLEAR WATER PUMPING FLOW m3/h']
        # Check if 'remarks category' is NaN and if the previous row had a non-NaN remark
        if pd.isna(current_remark):
            # Check if raw water and treated water columns are 0 or NaN
            if ((raw_water_flow == 0 or pd.isna(raw_water_flow)) and (clear_water_pumping_flow == 0 or pd.isna(clear_water_pumping_flow))):# or (('intake' in previous_remark) and (raw_water_flow == 0) and (clear_water_pumping_flow != 0)) or (('WTP' in previous_remark) and (raw_water_flow != 0) and (clear_water_pumping_flow == 0)):
                # Fill the current NaN remark with the previous non-NaN remark
                df.loc[i, 'remarks category'] = previous_remark
            elif previous_remark is not None and (('intake' in previous_remark and 'WTP' not in previous_remark and (raw_water_flow == 0 or pd.isna(raw_water_flow)) and clear_water_pumping_flow != 0) or ('WTP' in previous_remark and 'intake' not in previous_remark and raw_water_flow != 0 and (clear_water_pumping_flow == 0 or pd.isna(clear_water_pumping_flow)))):
                df.loc[i, 'remarks category'] = previous_remark
            elif previous_remark is not None and 'complaint at WTP' in previous_remark and (raw_water_flow == 0 or pd.isna(raw_water_flow)):
                df.loc[i, 'remarks category'] = previous_remark
#             elif previous_remark is not None and 'WTP cleaning' in previous_remark and (raw_water_flow == 0 or pd.isna(raw_water_flow)) and (clear_water_flow == 0 or pd.isna(clear_water_flow)):
#                 df.loc[i, 'remarks category'] = previous_remark
            else:
                previous_remark = current_remark
        else:
            # Update the previous_remark if the current remark is not NaN
            previous_remark = current_remark
 
    return df

# %%
# Apply the function to the DataFrame
df_filled = fill_remarks_category(df)

# %%
df_filled[df_filled['remarks category']=='WTP cleaning']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 22769        2022-01-09             18:00                    0.00
# 22770        2022-01-09             19:00                    0.00
# 22771        2022-01-09             20:00                    0.00
# 22772        2022-01-09             21:00                    0.00
# 22773        2022-01-09             22:00                    0.00
# 22774        2022-01-09             23:00                    0.00
# 22775        2022-01-09              0:00                    0.00
# 22776        2022-01-10              1:00                    0.00
# 22777        2022-01-10              2:00                    0.00
# 22778        2022-01-10              3:00                    0.00
# 22779        2022-01-10              4:00                    0.00
# 22780        2022-01-10              5:00                    0.00
# 22781        2022-01-10              6:00                    0.00
# 22782        2022-01-10              7:00                    0.00
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 0            2024-08-01              1:00                 2561.58
# 1            2024-08-01              2:00                 2510.71
# 2            2024-08-01              3:00                 2489.32
# 3            2024-08-01              4:00                 2444.78
# 4            2024-08-01              5:00                 2417.47
# ...                 ...               ...                     ...
# 24043        2021-12-31             20:00                 2499.51
# 24044        2021-12-31             21:00                 2477.10
# 24045        2021-12-31             22:00                 2470.76
# 24046        2021-12-31             23:00                 2492.04
# 24047        2021-12-31              0:00                 2494.18
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 0                                 2.32                        1996.36
# 1                                 2.49                        1984.73
# 2                                 2.71                        1998.56
# 3                                 2.79                        1972.01
# 4                                 2.99                        1945.42
# ...                                ...                            ...
# 24043                             2.89                        1851.25
# 24044                             3.06                        1878.95
# 24045                             3.25                        1913.29
# 24046                             3.30                        1904.43
# 24047                             3.33                        1896.67
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 0                               2479.10     NaN             None
# 1                               2429.87     NaN             None
# 2                               2409.16     NaN             None
# 3                               2366.06     NaN             None
# 4                               2339.63     NaN             None
# ...                                 ...     ...              ...
# 24043                           2419.03     NaN             None
# 24044                           2397.34     NaN             None
# 24045                           2391.20     NaN             None
# 24046                           2411.80     NaN             None
# 24047                           2413.87     NaN             None
#
# [24048 rows x 8 columns]

# %%
df_filled['remarks category'].value_counts()
# Out:
# Power Failure at Intake             118
# intake cleaning                      98
# maintanance                          72
# pipe line broken at thaliparamba     72
# Power Failure at intake and WTP      54
# WTP cleaning                         49
# distribution line maintanance        35
# complaint at WTP                     33
# Power Failure at WTP                 25
# maintanance at intake                22
# intake sump level low                22
# under voltage                        16
# maintanance at Thaliparamba          15
# intake pumping stopped               13
# channel cieaning                     10
# inlet chamber cleaning                4
# voltage fluctation at intake          4
# energy auditing                       1
# Name: remarks category, dtype: int64

# %%
df_filled[df_filled['remarks category']=='maintanance'].REMARKS.unique()
# Out:
# array(['pumping stopped for maintanance work & nhai work.', nan,
#        'gravity line air valve maintenance', 'stopped for maintanance'],
#       dtype=object)

# %%
df_filled[df_filled.REMARKS=='stopped for maintanance']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 12696        2023-08-14              1:00                     0.0
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 12696                             1.06                        1856.25
#
#        TREATED WATER PRODUCTION IN m3/h                  REMARKS  \
# 12696                               0.0  stopped for maintanance
#
#       remarks category
# 12696      maintanance

# %%
# df_filled[12696:12716]

# %%
# df_filled[5150:5189]

# %%
# df_filled[df_filled['remarks category']=='complaint at WTP']

# %%
# df[6200:6234]

# %%
df_filled[(df_filled['RAW WATER FLOW IN m3/h'].isna())&(df_filled['CLEAR WATER SUMP LEVEL IN Meter'].isna())&(df_filled['CLEAR WATER PUMPING FLOW m3/h'].isna())&(df_filled['TREATED WATER PRODUCTION IN m3/h']==0.0)&(df_filled['REMARKS'].isna())]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 9107         2023-06-17             12:00                     NaN
# 13127        2023-08-31              0:00                     NaN
# 16007        2022-11-30              0:00                     NaN
# 21071        2022-04-27              0:00                     NaN
# 21072        2022-04-28              1:00                     NaN
# 21073        2022-04-28              2:00                     NaN
# 21074        2022-04-28              3:00                     NaN
# 21075        2022-04-28              4:00                     NaN
# 21076        2022-04-28              5:00                     NaN
# 21077        2022-04-28              6:00                     NaN
# 21078        2022-04-28              7:00                     NaN
# 21079        2022-04-28              8:00                     NaN
# 21080        2022-04-28              9:00                     NaN
# 21081        2022-04-28             10:00                     NaN
# 21754        2022-03-26             11:00                     NaN
# 21755        2022-03-26             12:00                     NaN
# 21756        2022-03-26             13:00                     NaN
# 21757        2022-03-26             14:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 9107                               NaN                            NaN
# 13127                              NaN                            NaN
# 16007                              NaN                            NaN
# 21071                              NaN                            NaN
# 21072                              NaN                            NaN
# 21073                              NaN                            NaN
# 21074                              NaN                            NaN
# 21075                              NaN                            NaN
# 21076                              NaN                            NaN
# 21077                              NaN                            NaN
# 21078                              NaN                            NaN
# 21079                              NaN                            NaN
# 21080                              NaN                            NaN
# 21081                              NaN                            NaN
# 21754                              NaN                            NaN
# 21755                              NaN                            NaN
# 21756                              NaN                            NaN
# 21757                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS  \
# 9107                                0.0     NaN
# 13127                               0.0     NaN
# 16007                               0.0     NaN
# 21071                               0.0     NaN
# 21072                               0.0     NaN
# 21073                               0.0     NaN
# 21074                               0.0     NaN
# 21075                               0.0     NaN
# 21076                               0.0     NaN
# 21077                               0.0     NaN
# 21078                               0.0     NaN
# 21079                               0.0     NaN
# 21080                               0.0     NaN
# 21081                               0.0     NaN
# 21754                               0.0     NaN
# 21755                               0.0     NaN
# 21756                               0.0     NaN
# 21757                               0.0     NaN
#
#                       remarks category
# 9107   Power Failure at intake and WTP
# 13127                             None
# 16007                             None
# 21071      maintanance at Thaliparamba
# 21072      maintanance at Thaliparamba
# 21073      maintanance at Thaliparamba
# 21074      maintanance at Thaliparamba
# 21075      maintanance at Thaliparamba
# 21076      maintanance at Thaliparamba
# 21077      maintanance at Thaliparamba
# 21078      maintanance at Thaliparamba
# 21079      maintanance at Thaliparamba
# 21080      maintanance at Thaliparamba
# 21081      maintanance at Thaliparamba
# 21754          Power Failure at Intake
# 21755          Power Failure at Intake
# 21756          Power Failure at Intake
# 21757          Power Failure at Intake

# %%
df_filled[(df_filled['RAW WATER FLOW IN m3/h'].isna())&(df_filled['CLEAR WATER SUMP LEVEL IN Meter'].isna())&(df_filled['CLEAR WATER PUMPING FLOW m3/h'].isna())&(df_filled['TREATED WATER PRODUCTION IN m3/h']==0.0)&(df_filled['remarks category'].isna())]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 13127        2023-08-31              0:00                     NaN
# 16007        2022-11-30              0:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 13127                              NaN                            NaN
# 16007                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 13127                               0.0     NaN             None
# 16007                               0.0     NaN             None

# %%
df_filled[df_filled.Standardized_Date=='2022-11-30']
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 15984        2022-11-30              1:00                 3489.73
# 15985        2022-11-30              2:00                 3498.53
# 15986        2022-11-30              3:00                 3502.27
# 15987        2022-11-30              4:00                 2418.33
# 15988        2022-11-30              5:00                 2422.67
# 15989        2022-11-30              6:00                 2423.24
# 15990        2022-11-30              7:00                 2420.54
# 15991        2022-11-30              8:00                 3496.00
# 15992        2022-11-30              9:00                 3488.93
# 15993        2022-11-30             10:00                 3499.54
# 15994        2022-11-30             11:00                 3478.45
# 15995        2022-11-30             12:00                 3494.23
# 15996        2022-11-30             13:00                 3500.34
# 15997        2022-11-30             14:00                 3523.34
# 15998        2022-11-30             15:00                 3500.33
# 15999        2022-11-30             16:00                 3494.78
# 16000        2022-11-30             17:00                 3500.41
# 16001        2022-11-30             18:00                 3492.99
# 16002        2022-11-30             19:00                 3480.98
# 16003        2022-11-30             20:00                 2377.78
# 16004        2022-11-30             21:00                 2371.44
# 16005        2022-11-30             22:00                 2372.14
# 16006        2022-11-30             23:00                 2372.18
# 16007        2022-11-30              0:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
#
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 17040                             2.62                        2734.78
# 17041                             2.76                        2767.67
# 17042                             2.95                        2756.89
# 17043                             3.01                        1856.87
# 17044                             3.09                        1834.89
# 17045                             3.04                        1845.98
# 17046                             2.89                           0.00
# 17047                             2.77                           0.00
# 17048                             2.73                        2798.51
# 17049                             2.63                        2778.46
# 17050                             2.83                        2750.84
# 17051                             2.88                        2790.63
# 17052                             2.89                        2780.04
# 17053                             2.82                        2747.46
# 17054                             2.66                        2798.06
# 17055                             2.59                        2753.35
# 17056                             2.52                        2732.01
# 17057                             2.50                        2738.52
# 17058                             2.47                        2737.55
# 17059                             2.53                        2751.35
# 17060                             2.57                        2746.88
# 17061                             2.51                        2768.62
# 17062                             2.37                        1838.73
# 17063                             2.44                        1862.13
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 17040                           3012.10     NaN             None
# 17041                           2998.66     NaN             None
# 17042                           2945.45     NaN             None
# 17043                           2063.98     NaN             None
# 17044                           2096.24     NaN             None
# 17045                           2087.21     NaN             None
# 17046                              0.00     NaN             None
# 17047                              0.00     NaN             None
# 17048                           3158.36     NaN             None
# 17049                           3114.36     NaN             None
# 17050                           3101.33     NaN             None
# 17051                           3097.93     NaN             None
# 17052                           3061.75     NaN             None
# 17053                           3064.59     NaN             None
# 17054                           3074.91     NaN             None
# 17055                           3048.12     NaN             None
# 17056                           3042.04     NaN             None
# 17057                           3031.53     NaN             None
# 17058                           3041.16     NaN             None
# 17059                           3042.26     NaN             None
# 17060                           1831.06     NaN             None
# 17061                           1831.06     NaN             None
# 17062                           1831.06     NaN             None
# 17063                           2232.47     NaN             None

# %% [markdown]
# ## Treated water values which is less than raw water * 0.967
# It is corrected in the outlier detection code

# %%
# 16864	2022-09-05	17:00	3245.73	2.21	2750.28	0.00	NaN	None
# 16865	2022-09-05	18:00	3248.76	2.22	2759.43	0.00	NaN	None
# 10226	2023-05-03	3:00	3480.39	2.60	2826.56	1.00	NaN	None
# 15871	2022-11-25	8:00	3464.24	2.72	2813.92	0.00	NaN	None
# 16591	2022-10-25	8:00	3271.71	3.42	2789.43	0.00	NaN	None
# 17060	2022-09-13	21:00	3136.83	2.57	2746.88	1831.06	NaN	None
# 17061	2022-09-13	22:00	2313.16	2.51	2768.62	1831.06	NaN	None
# 17062	2022-09-13	23:00	2313.06	2.37	1838.73	1831.06	NaN	None
# 17585	2022-08-05	18:00	1834.58	2.78	0.00	0.00	NaN	None
# 18497	2022-07-12	18:00	2121.78	2.00	2770.12	0.00	NaN	None
# 19264	2022-06-13	17:00	3501.97	4.00	2798.10	1179.56	NaN	None
# 19175	2022-06-09	0:00	2392.02	2.52	1846.64	0.00	NaN	None
# 19895	2022-05-09	0:00	2530.68	1.55	2766.25	0.00	NaN	None

list_treated_error_index = [16864,16865,10226,15871,16591,17060,17061,17062,17585,18497,19264,19175,19895]
df_filled.loc[list_treated_error_index]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
#
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 12619        2023-08-10             20:00                 3261.45
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 12619                             2.69                        3662.46
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 12619                               NaN     NaN             None

# %%
df_filled.loc[df_filled[df_filled['TREATED WATER PRODUCTION IN m3/h'].isna()].index,'TREATED WATER PRODUCTION IN m3/h'] = (df_filled[df_filled['TREATED WATER PRODUCTION IN m3/h'].isna()]['RAW WATER FLOW IN m3/h']*0.967).round(2)

# %%
df_filled.loc[12619]
# Out:
# Standardized_Date                   2023-08-10 00:00:00
# STANDARDIZED_TIME                                 20:00
# RAW WATER FLOW IN m3/h                          3261.45
# CLEAR WATER SUMP LEVEL IN Meter                    2.69
# CLEAR WATER PUMPING FLOW m3/h                   3662.46
# TREATED WATER PRODUCTION IN m3/h                3153.82
# REMARKS                                             NaN
# remarks category                                   None
# Name: 12619, dtype: object

# %%
df_filled[df_filled['TREATED WATER PRODUCTION IN m3/h'].isna()]
# Out:
# Empty DataFrame
# Columns: [Standardized_Date, STANDARDIZED_TIME, RAW WATER FLOW IN m3/h, CLEAR WATER SUMP LEVEL IN Meter, CLEAR WATER PUMPING FLOW m3/h, TREATED WATER PRODUCTION IN m3/h, REMARKS, remarks category]
# Index: []

# %%
df_filled.loc[df_filled['remarks category'].notnull()] = df_filled.loc[df_filled['remarks category'].notnull()].fillna(0)

# %%
df_filled.isna().sum()
# Out:
# Standardized_Date                       0
# STANDARDIZED_TIME                       0
# RAW WATER FLOW IN m3/h                  2
# CLEAR WATER SUMP LEVEL IN Meter         7
# CLEAR WATER PUMPING FLOW m3/h           6
# TREATED WATER PRODUCTION IN m3/h        0
# REMARKS                             23385
# remarks category                    23385
# dtype: int64

# %%
df_filled[df_filled['RAW WATER FLOW IN m3/h'].isna()]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 13127        2023-08-31              0:00                     NaN
# 16007        2022-11-30              0:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 13127                              NaN                            NaN
# 16007                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 13127                               0.0     NaN             None
# 16007                               0.0     NaN             None

# %%
df_filled[df_filled['CLEAR WATER SUMP LEVEL IN Meter'].isna()]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 321          2024-08-14             10:00                     0.0
# 2604         2024-05-20             13:00                     0.0
# 2605         2024-05-20             14:00                     0.0
# 2606         2024-05-20             15:00                     0.0
# 4911         2024-02-24             16:00                     0.0
# 13127        2023-08-31              0:00                     NaN
# 16007        2022-11-30              0:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 321                                NaN                            0.0
# 2604                               NaN                            0.0
# 2605                               NaN                            0.0
# 2606                               NaN                            0.0
# 4911                               NaN                            0.0
# 13127                              NaN                            NaN
# 16007                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 321                                 0.0     NaN             None
# 2604                                0.0     NaN             None
# 2605                                0.0     NaN             None
# 2606                                0.0     NaN             None
# 4911                                0.0     NaN             None
# 13127                               0.0     NaN             None
# 16007                               0.0     NaN             None

# %%
sump_list = [321,2604,2605,2606,4911]
df_filled.loc[sump_list,'CLEAR WATER SUMP LEVEL IN Meter'] = 0.0
df_filled[df_filled['CLEAR WATER SUMP LEVEL IN Meter'].isna()]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 13127        2023-08-31              0:00                     NaN
# 16007        2022-11-30              0:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 13127                              NaN                            NaN
# 16007                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 13127                               0.0     NaN             None
# 16007                               0.0     NaN             None

# %%
df_filled[df_filled['CLEAR WATER PUMPING FLOW m3/h'].isna()]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 2779         2024-05-27             20:00                 3409.31
# 8638         2023-09-27             23:00                 3256.67
# 8687         2023-09-29              0:00                 2287.43
# 13127        2023-08-31              0:00                     NaN
# 16007        2022-11-30              0:00                     NaN
# 23310        2021-12-01              7:00                 2410.13
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 2779                              3.41                            NaN
# 8638                              2.82                            NaN
# 8687                              1.75                            NaN
# 13127                              NaN                            NaN
# 16007                              NaN                            NaN
# 23310                             3.35                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 2779                            3299.53     NaN             None
# 8638                            3151.81     NaN             None
# 8687                            2213.77     NaN             None
# 13127                              0.00     NaN             None
# 16007                              0.00     NaN             None
# 23310                           2332.52     NaN             None

# %%
clear_water_list = [2779,8638,8687,23310]
df_filled.loc[clear_water_list,'CLEAR WATER PUMPING FLOW m3/h'] = 0.0
df_filled[df_filled['CLEAR WATER PUMPING FLOW m3/h'].isna()]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 13127        2023-08-31              0:00                     NaN
# 16007        2022-11-30              0:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 13127                              NaN                            NaN
# 16007                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h REMARKS remarks category
# 13127                               0.0     NaN             None
# 16007                               0.0     NaN             None

# %%
df_filled.REMARKS.fillna('No remarks', inplace=True)
df_filled.REMARKS.replace(0.0,'No remarks', inplace=True)
df_filled['remarks category'].fillna('No remarks', inplace=True)
# df_filled.loc[df_filled['remarks category'].isnull()] = df_filled.loc[df_filled['remarks category'].isnull()].fillna(0)

# %%
df_filled.isna().sum()
# Out:
# Standardized_Date                   0
# STANDARDIZED_TIME                   0
# RAW WATER FLOW IN m3/h              2
# CLEAR WATER SUMP LEVEL IN Meter     2
# CLEAR WATER PUMPING FLOW m3/h       2
# TREATED WATER PRODUCTION IN m3/h    0
# REMARKS                             0
# remarks category                    0
# dtype: int64

# %% [markdown]
# ## Outlier detection

# %%
df_filled.loc[[3355,6791]]
# Out:
#      Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 3355        2024-04-20             20:00                13489.25
# 6791        2023-11-11              0:00                62411.58
#
#       CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 3355                             3.61                        3812.47
# 6791                             2.01                        2799.64
#
#       TREATED WATER PRODUCTION IN m3/h     REMARKS remarks category
# 3355                          13054.90  No remarks       No remarks
# 6791                          60401.93  No remarks       No remarks

# %%
# Change the value at index 3355(13489.25)
df_filled.loc[3355, 'RAW WATER FLOW IN m3/h'] = 3489.25
df_filled.loc[3355, 'TREATED WATER PRODUCTION IN m3/h'] = 3489.25*0.967

# Change the value at index 6791(62411.58)
df_filled.loc[6791, 'RAW WATER FLOW IN m3/h'] = 2411.58
df_filled.loc[6791, 'TREATED WATER PRODUCTION IN m3/h'] = 2411.58*0.967

# %%
def raw_water_outlier_ffill(data, column_name1,column_name2,column_name3, threshold=4000):
    for i in range(1, len(data)):
        # If the value is greater than the threshold
        if data.loc[i, column_name1] >= threshold:
            # Forward fill using the previous value
            data.loc[i, column_name1] = data.loc[i, column_name1] * 0.1
            data.loc[i,'TREATED WATER PRODUCTION IN m3/h'] = (data.loc[i, column_name1]*0.967).round(2)
    for i in range(1, len(data)):
        # If the value is greater than the threshold
        treated_water = (data.loc[i,'TREATED WATER PRODUCTION IN m3/h']/df_filled.loc[i,column_name1]).round(2)
        if treated_water < 0.96:
            data.loc[i,'TREATED WATER PRODUCTION IN m3/h'] = (data.loc[i, column_name1]*0.967).round(2)
    for i in range(1, len(data)):
        # If the value is greater than the threshold
        if data.loc[i, column_name2] > 5:
            # Forward fill using the previous value
            data.loc[i, column_name2] = data.loc[i-1, column_name2]
    # Adjusting values in column_name3
    for i in range(1, len(data)):
        if data.loc[i, column_name3] > threshold:
            # For specific indices, perform forward fill
            if i in [6976,1757,21314, 21315, 21316]:
                data.loc[i, column_name3] = data.loc[i - 1, column_name3]
            else:
                # Check the number of digits
                value_str = str(int(data.loc[i, column_name3]))  # Convert to string for digit length check
                if len(value_str) == 6:
                    data.loc[i, column_name3] = data.loc[i, column_name3] * 0.01
                elif len(value_str) == 5:
                    data.loc[i, column_name3] = data.loc[i, column_name3] * 0.1
    return data

# %%
df_filled = raw_water_outlier_ffill(df_filled,'RAW WATER FLOW IN m3/h','CLEAR WATER SUMP LEVEL IN Meter','CLEAR WATER PUMPING FLOW m3/h')
df_filled
# Out:
# /var/folders/z1/t4ljwcrd4s7cs37mhvm494m00000gn/T/ipykernel_35040/178441967.py:10: RuntimeWarning: invalid value encountered in scalar divide
#   treated_water = (data.loc[i,'TREATED WATER PRODUCTION IN m3/h']/df_filled.loc[i,column_name1]).round(2)
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 0            2024-08-01              1:00                 2561.58
# 1            2024-08-01              2:00                 2510.71
# 2            2024-08-01              3:00                 2489.32
# 3            2024-08-01              4:00                 2444.78
# 4            2024-08-01              5:00                 2417.47
# ...                 ...               ...                     ...
# 24043        2021-12-31             20:00                 2499.51
# 24044        2021-12-31             21:00                 2477.10
# 24045        2021-12-31             22:00                 2470.76
# 24046        2021-12-31             23:00                 2492.04
# 24047        2021-12-31              0:00                 2494.18
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 0                                 2.32                        1996.36
# 1                                 2.49                        1984.73
# 2                                 2.71                        1998.56
# 3                                 2.79                        1972.01
# 4                                 2.99                        1945.42
# ...                                ...                            ...
# 24043                             2.89                        1851.25
# 24044                             3.06                        1878.95
# 24045                             3.25                        1913.29
# 24046                             3.30                        1904.43
# 24047                             3.33                        1896.67
#
#        TREATED WATER PRODUCTION IN m3/h     REMARKS remarks category
# 0                               2479.10  No remarks       No remarks
# 1                               2429.87  No remarks       No remarks
# 2                               2409.16  No remarks       No remarks
# 3                               2366.06  No remarks       No remarks
# 4                               2339.63  No remarks       No remarks
# ...                                 ...         ...              ...
# 24043                           2419.03  No remarks       No remarks
# 24044                           2397.34  No remarks       No remarks
# 24045                           2391.20  No remarks       No remarks
# 24046                           2411.80  No remarks       No remarks
# 24047                           2413.87  No remarks       No remarks
#
# [24048 rows x 8 columns]

# %%
df_filled.dtypes
# Out:
# Standardized_Date                   datetime64[ns]
# STANDARDIZED_TIME                           object
# RAW WATER FLOW IN m3/h                     float64
# CLEAR WATER SUMP LEVEL IN Meter            float64
# CLEAR WATER PUMPING FLOW m3/h              float64
# TREATED WATER PRODUCTION IN m3/h           float64
# REMARKS                                     object
# remarks category                            object
# dtype: object

# %%
df_filled['STANDARDIZED_TIME'] = pd.to_datetime(df_filled['STANDARDIZED_TIME'],format='%H:%M').dt.time
df_filled=df_filled.sort_values(by=['Standardized_Date','STANDARDIZED_TIME'],ascending=True).reset_index(drop=True)

# %%
df_filled.dtypes
# Out:
# Standardized_Date                  datetime64[ns]
# STANDARDIZED_TIME                          object
# RAW WATER FLOW IN ML                      float64
# CLEAR WATER SUMP LEVEL IN Meter           float64
# CLEAR WATER PUMPING FLOW ML               float64
# TREATED WATER PRODUCTION IN ML            float64
# REMARKS                                    object
# remarks category                           object
# dtype: object

# %%
df_filled.isna().sum()
# Out:
# Standardized_Date                   0
# STANDARDIZED_TIME                   0
# RAW WATER FLOW IN m3/h              2
# CLEAR WATER SUMP LEVEL IN Meter     2
# CLEAR WATER PUMPING FLOW m3/h       2
# TREATED WATER PRODUCTION IN m3/h    0
# REMARKS                             0
# remarks category                    0
# dtype: int64

# %%
df_filled[df_filled['CLEAR WATER PUMPING FLOW m3/h'].isna()]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 8736         2022-11-30          00:00:00                     NaN
# 15312        2023-08-31          00:00:00                     NaN
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 8736                               NaN                            NaN
# 15312                              NaN                            NaN
#
#        TREATED WATER PRODUCTION IN m3/h     REMARKS remarks category
# 8736                                0.0  No remarks       No remarks
# 15312                               0.0  No remarks       No remarks

# %%
indexes_to_fill = [8736,15312]
columns_to_fill = ['RAW WATER FLOW IN m3/h', 'CLEAR WATER PUMPING FLOW m3/h', 'CLEAR WATER SUMP LEVEL IN Meter']
# df_filled.loc[indexes_to_fill, columns_to_fill] = df_filled[columns_to_fill].bfill()
df_filled.loc[indexes_to_fill] = df_filled.bfill()

# %%
df_filled[df_filled['CLEAR WATER PUMPING FLOW m3/h'].isna()]
# Out:
# Empty DataFrame
# Columns: [Standardized_Date, STANDARDIZED_TIME, RAW WATER FLOW IN m3/h, CLEAR WATER SUMP LEVEL IN Meter, CLEAR WATER PUMPING FLOW m3/h, TREATED WATER PRODUCTION IN m3/h, REMARKS, remarks category]
# Index: []

# %%
df_filled.loc[indexes_to_fill]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 8736         2022-11-30          00:00:00                 3489.73
# 15312        2023-08-31          00:00:00                 3365.06
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 8736                              2.71                        2739.76
# 15312                             2.75                        2866.06
#
#        TREATED WATER PRODUCTION IN m3/h     REMARKS remarks category
# 8736                                0.0  No remarks       No remarks
# 15312                               0.0  No remarks       No remarks

# %%
df_filled.loc[indexes_to_fill,'TREATED WATER PRODUCTION IN m3/h'] = ((df_filled.loc[indexes_to_fill,'RAW WATER FLOW IN m3/h'])*0.967).round(2)

# %%
((df_filled.loc[indexes_to_fill]['RAW WATER FLOW IN m3/h'])*0.967).round(2)
# Out:
# 8736     3374.57
# 15312    3254.01
# Name: RAW WATER FLOW IN m3/h, dtype: float64

# %%
df_filled.loc[indexes_to_fill]
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN m3/h  \
# 8736         2022-11-30          00:00:00                 3489.73
# 15312        2023-08-31          00:00:00                 3365.06
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW m3/h  \
# 8736                              2.71                        2739.76
# 15312                             2.75                        2866.06
#
#        TREATED WATER PRODUCTION IN m3/h     REMARKS remarks category
# 8736                            3374.57  No remarks       No remarks
# 15312                           3254.01  No remarks       No remarks

# %%
df_filled.isna().sum()
# Out:
# Standardized_Date                   0
# STANDARDIZED_TIME                   0
# RAW WATER FLOW IN m3/h              0
# CLEAR WATER SUMP LEVEL IN Meter     0
# CLEAR WATER PUMPING FLOW m3/h       0
# TREATED WATER PRODUCTION IN m3/h    0
# REMARKS                             0
# remarks category                    0
# dtype: int64

# %%
df_filled.to_csv('final_data.csv', index=False)

# %% [markdown]
# ## Convert m3/h to ML (Megaliters)

# %%
flow_in_ML= ['RAW WATER FLOW IN m3/h','CLEAR WATER PUMPING FLOW m3/h',
       'TREATED WATER PRODUCTION IN m3/h']
df_filled[flow_in_ML]= df_filled[flow_in_ML]*0.001

# %%
df_filled.rename(columns={'RAW WATER FLOW IN m3/h': 'RAW WATER FLOW IN ML','CLEAR WATER PUMPING FLOW m3/h':'CLEAR WATER PUMPING FLOW ML','TREATED WATER PRODUCTION IN m3/h':'TREATED WATER PRODUCTION IN ML'}, inplace=True)

# %%
df_filled
# Out:
#       Standardized_Date STANDARDIZED_TIME  RAW WATER FLOW IN ML  \
# 0            2021-12-01          00:00:00               3.52301
# 1            2021-12-01          01:00:00               3.51043
# 2            2021-12-01          02:00:00               3.49087
# 3            2021-12-01          03:00:00               3.50543
# 4            2021-12-01          04:00:00               3.51556
# ...                 ...               ...                   ...
# 24043        2024-08-28          19:00:00               3.13486
# 24044        2024-08-28          20:00:00               3.17401
# 24045        2024-08-28          21:00:00               3.13113
# 24046        2024-08-28          22:00:00               3.16261
# 24047        2024-08-28          23:00:00               3.14265
#
#        CLEAR WATER SUMP LEVEL IN Meter  CLEAR WATER PUMPING FLOW ML  \
# 0                                 2.10                      2.70209
# 1                                 2.84                      2.77743
# 2                                 3.12                      2.79467
# 3                                 3.44                      2.79543
# 4                                 3.72                      2.79826
# ...                                ...                          ...
# 24043                             3.46                      2.87175
# 24044                             3.63                      2.85830
# 24045                             3.64                      2.87098
# 24046                             3.49                      2.89001
# 24047                             3.52                      2.86865
#
#        TREATED WATER PRODUCTION IN ML     REMARKS remarks category
# 0                             3.40957  No remarks       No remarks
# 1                             3.39739  No remarks       No remarks
# 2                             3.37846  No remarks       No remarks
# 3                             3.39256  No remarks       No remarks
# 4                             3.40236  No remarks       No remarks
# ...                               ...         ...              ...
# 24043                         3.03392  No remarks       No remarks
# 24044                         3.07181  No remarks       No remarks
# 24045                         3.03031  No remarks       No remarks
# 24046                         3.06077  No remarks       No remarks
# 24047                         3.04146  No remarks       No remarks
#
# [24048 rows x 8 columns]

# %%
df_filled.to_csv('final_data_in_ML.csv',index=False)
