# %%
import pandas as pd

# %%
data_ebill = pd.read_csv('11kV bill_units.csv')
data_ebill
# Out:
#         Month    Year     CD  75% CD  130% CD  Connected Load  MD Avg  \
# 0    November  2021.0  670.0   502.5    871.0          1436.0  504.87
# 1    December  2021.0  670.0   502.5    871.0          1436.0  505.57
# 2     January  2022.0  670.0   502.5    871.0          1436.0  505.34
# 3    February  2022.0  670.0   502.5    871.0          1436.0  509.56
# 4       March  2022.0  670.0   502.5    871.0          1436.0  514.54
# 5       April  2022.0  670.0   502.5    871.0          1436.0  514.92
# 6         May  2022.0  670.0   502.5    871.0          1436.0  515.34
# 7        June  2022.0  670.0   502.5    871.0          1436.0  512.89
# 8        July  2022.0  670.0   502.5    871.0          1436.0  509.77
# 9      August  2022.0  670.0   502.5    871.0          1436.0  505.65
# 10  September  2022.0  670.0   502.5    871.0          1436.0  504.95
# 11    October  2022.0  670.0   502.5    871.0          1436.0  502.89
# ...

# %%
data_ebill.shape
# Out:
# (34, 31)

# %%
data_ebill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Month                  31 non-null     object
#  1   Year                   31 non-null     float64
#  2   CD                     31 non-null     float64
#  3   75% CD                 31 non-null     float64
#  4   130% CD                31 non-null     float64
#  5   Connected Load         31 non-null     float64
#  6   MD Avg                 29 non-null     float64
#  7   Avg_Consumption (kWh)  29 non-null     float64
#  8   Units_kWh              29 non-null     float64
#  9   PF Avg                 29 non-null     float64
#  10  Z1 (kWh)               29 non-null     float64
#  11  Z2 (kWh)               29 non-null     float64
#  12  Z3 (kWh)               29 non-null     float64
#  13  Z1 kVArh (lag)         29 non-null     float64
# ...
